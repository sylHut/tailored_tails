# %%
# Import the required modules
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
# %matplotlib inline

# %% [markdown]
# # Loading and Preprocessing Data

# %%
# Read the preprocessed_doggy file into a DataFrame
doggy_df = pd.read_csv(
    Path("preprocessed_doggy.csv")
)

# Review the DataFrame
display(doggy_df.head())
display(doggy_df.tail())
# Out:
#    Unnamed: 0    Borough dog_friendly income_cat  grooming_frequency  \
# 0           0      Bronx          Yes     middle                 0.4
# 1           1  Manhattan          Yes       high                 0.8
# 2           2  Manhattan          Yes       high                 1.0
# 3           3   Brooklyn          Yes        low                 0.4
# 4           4   Brooklyn          Yes       high                 0.4
#
#    shedding  energy_level  trainability  demeanor          size  \
# 0       0.4           0.8           0.8       1.0  Small 9-35lb
# 1       0.2           0.6           0.6       1.0      Toy >9lb
# 2       0.2           0.6           0.2       0.8      Toy >9lb
# 3       0.8           0.6           1.0       0.6  Small 9-35lb
# 4       0.4           0.4           1.0       0.8      Toy >9lb
#
#    life_expectancy lifetime_cost                          Breed
# 0              0.6           Low                          Boxer
# 1              0.8        Medium                        Maltese
# 2              0.8        Medium              Yorkshire Terrier
# 3              0.4           Low            German Shepherd Dog
# 4              0.8        Medium  Cavalier King Charles Spaniel
#         Unnamed: 0        Borough dog_friendly income_cat  grooming_frequency  \
# 275750      275750         Queens          Yes     middle                 1.0
# 275751      275751      Manhattan          Yes       high                 0.4
# 275752      275752       Brooklyn           No     middle                 0.2
# 275753      275753  Staten Island           No     middle                 0.4
# 275754      275754         Queens           No     middle                 0.4
#
#         shedding  energy_level  trainability  demeanor          size  \
# 275750       0.2           0.6           0.2       0.8      Toy >9lb
# 275751       0.4           0.4           1.0       0.8      Toy >9lb
# 275752       0.4           0.6           0.4       0.6      Toy >9lb
# 275753       0.8           1.0           1.0       1.0  Small 9-35lb
# 275754       0.2           0.6           1.0       1.0      Toy >9lb
#
#         life_expectancy lifetime_cost                          Breed
# 275750              0.8        Medium              Yorkshire Terrier
# 275751              0.8        Medium  Cavalier King Charles Spaniel
# 275752              1.0          High                      Chihuahua
# 275753              0.6        Medium             Labrador Retriever
# 275754              0.8           Low                 Boston Terrier

# %%
# Remove the Unnamed col
doggy_df = doggy_df[['Borough', 'dog_friendly', 'income_cat',
       'grooming_frequency', 'shedding', 'energy_level', 'trainability',
       'demeanor', 'size', 'life_expectancy', 'lifetime_cost', 'Breed']]

doggy_df.head()
# Out:
#      Borough dog_friendly income_cat  grooming_frequency  shedding  \
# 0      Bronx          Yes     middle                 0.4       0.4
# 1  Manhattan          Yes       high                 0.8       0.2
# 2  Manhattan          Yes       high                 1.0       0.2
# 3   Brooklyn          Yes        low                 0.4       0.8
# 4   Brooklyn          Yes       high                 0.4       0.4
#
#    energy_level  trainability  demeanor          size  life_expectancy  \
# 0           0.8           0.8       1.0  Small 9-35lb              0.6
# 1           0.6           0.6       1.0      Toy >9lb              0.8
# 2           0.6           0.2       0.8      Toy >9lb              0.8
# 3           0.6           1.0       0.6  Small 9-35lb              0.4
# 4           0.4           1.0       0.8      Toy >9lb              0.8
#
#   lifetime_cost                          Breed
# 0           Low                          Boxer
# 1        Medium                        Maltese
# 2        Medium              Yorkshire Terrier
# 3           Low            German Shepherd Dog
# 4        Medium  Cavalier King Charles Spaniel

# %%
# Define features set
X = doggy_df.copy()
X.drop("Breed", axis=1, inplace=True)
X.head()
# Out:
#      Borough dog_friendly income_cat  grooming_frequency  shedding  \
# 0      Bronx          Yes     middle                 0.4       0.4
# 1  Manhattan          Yes       high                 0.8       0.2
# 2  Manhattan          Yes       high                 1.0       0.2
# 3   Brooklyn          Yes        low                 0.4       0.8
# 4   Brooklyn          Yes       high                 0.4       0.4
#
#    energy_level  trainability  demeanor          size  life_expectancy  \
# 0           0.8           0.8       1.0  Small 9-35lb              0.6
# 1           0.6           0.6       1.0      Toy >9lb              0.8
# 2           0.6           0.2       0.8      Toy >9lb              0.8
# 3           0.6           1.0       0.6  Small 9-35lb              0.4
# 4           0.4           1.0       0.8      Toy >9lb              0.8
#
#   lifetime_cost
# 0           Low
# 1        Medium
# 2        Medium
# 3           Low
# 4        Medium

# %%
# Define target vector
y = doggy_df["Breed"].ravel()
y[:5]
# Out:
# array(['Boxer', 'Maltese', 'Yorkshire Terrier', 'German Shepherd Dog',
#        'Cavalier King Charles Spaniel'], dtype=object)

# %%
# Use LabelEncoder to convert targets(50) into a single column
# Use LabelEncoder on the y DataFrame to encode the Dog Breeds
label_encoder_df = LabelEncoder()

# Encode Labels
y_encoded = label_encoder_df.fit_transform(y)

# Test the results of the encoder
# Display first 50 of encoded column
display(y_encoded[0:50])

# Get the original labels back
display(label_encoder_df.inverse_transform(y_encoded[0:50]))
# Out:
# array([10, 30, 49, 24, 14, 14, 10, 10,  3, 28,  3, 25,  3, 49, 29,  9,  6,
#        25, 26,  6, 14, 10, 15, 30, 15, 29, 15, 49,  3,  6, 44, 29, 44,  3,
#        26, 16,  3, 23, 45, 37, 10, 15, 29, 12, 43, 39, 49, 28, 15, 30])
# array(['Boxer', 'Maltese', 'Yorkshire Terrier', 'German Shepherd Dog',
#        'Cavalier King Charles Spaniel', 'Cavalier King Charles Spaniel',
#        'Boxer', 'Boxer', 'Beagle', 'Havanese', 'Beagle',
#        'German Shorthaired Pointer', 'Beagle', 'Yorkshire Terrier',
#        'Labrador Retriever', 'Boston Terrier', 'Bichon Frise',
#        'German Shorthaired Pointer', 'Golden Retriever', 'Bichon Frise',
#        'Cavalier King Charles Spaniel', 'Boxer', 'Chihuahua', 'Maltese',
#        'Chihuahua', 'Labrador Retriever', 'Chihuahua',
#        'Yorkshire Terrier', 'Beagle', 'Bichon Frise', 'Shih Tzu',
#        'Labrador Retriever', 'Shih Tzu', 'Beagle', 'Golden Retriever',
#        'Cocker Spaniel', 'Beagle', 'French Bulldog', 'Siberian Husky',
#        'Poodle', 'Boxer', 'Chihuahua', 'Labrador Retriever', 'Bulldog',
#        'Shiba Inu', 'Pug', 'Yorkshire Terrier', 'Havanese', 'Chihuahua',
#        'Maltese'], dtype=object)

# %%
# Use get_dummies to convert category types to numbers
y = pd.get_dummies(y, dtype=int)
X = pd.get_dummies(X, dtype=int)

# %%
display(y.sample(10))
display(X.head(3))
# Out:
#         Australian Cattle Dog  Australian Shepherd  Basset Hound  Beagle  \
# 189254                      0                    0             0       0
# 244519                      0                    0             0       0
# 53921                       0                    0             0       0
# 172978                      0                    0             0       1
# 195283                      0                    0             0       0
# 249078                      0                    0             0       0
# 19608                       0                    0             0       0
# 18154                       0                    0             0       0
# 198267                      0                    1             0       0
# 224177                      0                    0             0       0
#
#         Belgian Malinois  Bernese Mountain Dog  Bichon Frise  Bloodhound  \
# 189254                 0                     0             0           0
# 244519                 0                     1             0           0
# 53921                  0                     0             0           0
# 172978                 0                     0             0           0
# 195283                 0                     0             0           0
# 249078                 0                     0             0           0
# 19608                  0                     0             0           0
# 18154                  0                     0             0           0
# 198267                 0                     0             0           0
# 224177                 0                     0             0           0
#
#         Border Collie  Boston Terrier  ...  Rhodesian Ridgeback  Rottweiler  \
# 189254              0               0  ...                    0           0
# 244519              0               0  ...                    0           0
# 53921               0               0  ...                    0           0
# 172978              0               0  ...                    0           0
# 195283              0               0  ...                    0           0
# 249078              0               0  ...                    0           0
# 19608               0               0  ...                    0           0
# 18154               0               0  ...                    0           0
# 198267              0               0  ...                    0           0
# 224177              0               0  ...                    0           0
#
#         Shetland Sheepdog  Shiba Inu  Shih Tzu  Siberian Husky  Vizsla  \
# 189254                  0          0         1               0       0
# 244519                  0          0         0               0       0
# 53921                   0          0         0               0       0
# 172978                  0          0         0               0       0
# 195283                  0          0         0               0       0
# 249078                  0          0         0               0       0
# 19608                   0          0         0               0       0
# 18154                   0          0         0               0       0
# 198267                  0          0         0               0       0
# 224177                  0          0         1               0       0
#
#         Weimaraner  West Highland White Terrier  Yorkshire Terrier
# 189254           0                            0                  0
# 244519           0                            0                  0
# 53921            0                            0                  0
# 172978           0                            0                  0
# 195283           0                            0                  0
# 249078           0                            0                  0
# 19608            0                            0                  0
# 18154            0                            0                  0
# 198267           0                            0                  0
# 224177           0                            0                  0
#
# [10 rows x 50 columns]
#    grooming_frequency  shedding  energy_level  trainability  demeanor  \
# 0                 0.4       0.4           0.8           0.8       1.0
# 1                 0.8       0.2           0.6           0.6       1.0
# 2                 1.0       0.2           0.6           0.2       0.8
#
#    life_expectancy  Borough_Bronx  Borough_Brooklyn  Borough_Manhattan  \
# 0              0.6              1                 0                  0
# 1              0.8              0                 0                  1
# 2              0.8              0                 0                  1
#
#    Borough_Queens  ...  income_cat_low  income_cat_middle  size_Giant <75lb  \
# 0               0  ...               0                  1                 0
# 1               0  ...               0                  0                 0
# 2               0  ...               0                  0                 0
#
#    size_Large 55-75lb  size_Medium 35-55lb  size_Small 9-35lb  size_Toy >9lb  \
# 0                   0                    0                  1              0
# 1                   0                    0                  0              1
# 2                   0                    0                  0              1
#
#    lifetime_cost_High  lifetime_cost_Low  lifetime_cost_Medium
# 0                   0                  1                     0
# 1                   0                  0                     1
# 2                   0                  0                     1
#
# [3 rows x 24 columns]

# %%
# Convert Features/Targets into a form suitable for Modeling
y = y_encoded
X = pd.get_dummies(X, dtype=int)

# %%
# Look at X, y data
display(y)
display(X.head(3))
# Out:
# array([10, 30, 49, ..., 15, 29,  9])
#    grooming_frequency  shedding  energy_level  trainability  demeanor  \
# 0                 0.4       0.4           0.8           0.8       1.0
# 1                 0.8       0.2           0.6           0.6       1.0
# 2                 1.0       0.2           0.6           0.2       0.8
#
#    life_expectancy  Borough_Bronx  Borough_Brooklyn  Borough_Manhattan  \
# 0              0.6              1                 0                  0
# 1              0.8              0                 0                  1
# 2              0.8              0                 0                  1
#
#    Borough_Queens  ...  income_cat_low  income_cat_middle  size_Giant <75lb  \
# 0               0  ...               0                  1                 0
# 1               0  ...               0                  0                 0
# 2               0  ...               0                  0                 0
#
#    size_Large 55-75lb  size_Medium 35-55lb  size_Small 9-35lb  size_Toy >9lb  \
# 0                   0                    0                  1              0
# 1                   0                    0                  0              1
# 2                   0                    0                  0              1
#
#    lifetime_cost_High  lifetime_cost_Low  lifetime_cost_Medium
# 0                   0                  1                     0
# 1                   0                  0                     1
# 2                   0                  0                     1
#
# [3 rows x 24 columns]

# %%
# Splitting into Train and Test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Creating StandardScaler instance
scaler = StandardScaler()

# %%
# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)

# %%
# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Fitting the Random Forest Model

# %%
# Create a random forest classifier
rf_model = RandomForestClassifier(n_estimators=500, random_state=78)

# %%
# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# %% [markdown]
# # Making Predictions Using the Random Forest Model¶

# %%
# Making predictions using the testing data
predictions = rf_model.predict(X_test_scaled)

# %% [markdown]
# # Feature Importance

# %%
# Random Forests in sklearn will automatically calculate feature importance
importances = rf_model.feature_importances_
# We can sort the features by their importance
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.16213005000823208, 'trainability'),
#  (0.16176114342035233, 'grooming_frequency'),
#  (0.13909463824174786, 'demeanor'),
#  (0.12253598112658234, 'shedding'),
#  (0.11439386867732662, 'life_expectancy'),
#  (0.07567969575083378, 'energy_level'),
#  (0.04763114617651003, 'size_Toy >9lb'),
#  (0.042355244303827436, 'lifetime_cost_Medium'),
#  (0.042026155344270226, 'size_Small 9-35lb'),
#  (0.03984502225264948, 'lifetime_cost_High'),
#  (0.036823665125355357, 'lifetime_cost_Low'),
#  (0.007489095130268015, 'size_Medium 35-55lb'),
#  (0.0018753487572728002, 'size_Giant <75lb'),
#  (0.0016401972110504832, 'size_Large 55-75lb'),
#  (0.0015394875519641642, 'income_cat_high'),
#  (0.000978568861411791, 'Borough_Manhattan'),
#  (0.000758538627533846, 'income_cat_low'),
#  (0.0003227862497923129, 'income_cat_middle'),
#  (0.00027185345747921365, 'Borough_Queens'),
#  (0.00024052286682900635, 'Borough_Bronx'),
#  (0.00022830231620866526, 'Borough_Brooklyn'),
#  (0.0001951581091748421, 'Borough_Staten Island'),
#  (9.307978195772827e-05, 'dog_friendly_No'),
#  (9.045065136957598e-05, 'dog_friendly_Yes')]

# %%
# Visualize the features by importance
importances_df = pd.DataFrame(sorted(zip(rf_model.feature_importances_, X.columns), reverse=True))
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)
# Out:
# <Axes: title={'center': 'Features Importances'}, ylabel='1'>

# %% [markdown]
# # Model Evaluation

# %%
# Calculating the accuracy score
acc_score = accuracy_score(y_test, predictions)
print(f"Accuracy Score : {acc_score}")
# Out:
# Accuracy Score : 0.9995213159459813

# %%
# Calculating the confusion matrix
cm = confusion_matrix(y_test, predictions)
print(cm)
# Out:
# [[ 344    0    0 ...    0    0    0]
#  [   0 1411    0 ...    0    0    0]
#  [   0    0  156 ...    0    0    0]
#  ...
#  [   0    0    0 ...  168    0    0]
#  [   0    0    0 ...    0  260    0]
#  [   0    0    0 ...    0    0 8688]]

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       344
#            1       1.00      1.00      1.00      1411
#            2       1.00      1.00      1.00       156
#            3       1.00      1.00      1.00      2225
#            4       1.00      1.00      1.00       116
#            5       1.00      1.00      1.00       343
#            6       1.00      1.00      1.00      1245
#            7       0.00      0.00      0.00        33
#            8       1.00      1.00      1.00       487
#            9       1.00      1.00      1.00      1329
#           10       1.00      1.00      1.00       991
#           11       1.00      1.00      1.00        24
#           12       1.00      1.00      1.00       278
#           13       1.00      1.00      1.00       277
#           14       1.00      1.00      1.00      1792
#           15       1.00      1.00      1.00      6034
#           16       1.00      1.00      1.00      1445
#           17       1.00      1.00      1.00        93
#           18       1.00      1.00      1.00      1116
#           19       1.00      1.00      1.00       112
#           20       1.00      1.00      1.00       318
#           21       1.00      1.00      1.00       133
#           22       1.00      1.00      1.00       110
#           23       1.00      1.00      1.00      2249
#           24       1.00      1.00      1.00      2091
#           25       1.00      1.00      1.00       125
#           26       1.00      1.00      1.00      2281
#           27       1.00      1.00      1.00       187
#           28       1.00      1.00      1.00      2609
#           29       1.00      1.00      1.00      4581
#           30       1.00      1.00      1.00      4443
#           31       1.00      1.00      1.00        86
#           32       1.00      1.00      1.00       129
#           33       1.00      1.00      1.00       845
#           34       1.00      1.00      1.00        88
#           35       1.00      1.00      1.00       489
#           36       1.00      1.00      1.00      2964
#           37       1.00      1.00      1.00      1747
#           38       1.00      1.00      1.00       168
#           39       1.00      1.00      1.00      1419
#           40       0.89      1.00      0.94       261
#           41       1.00      1.00      1.00       580
#           42       1.00      1.00      1.00       316
#           43       1.00      1.00      1.00      1901
#           44       1.00      1.00      1.00      7978
#           45       1.00      1.00      1.00      1623
#           46       1.00      1.00      1.00       251
#           47       1.00      1.00      1.00       168
#           48       1.00      1.00      1.00       260
#           49       1.00      1.00      1.00      8688
#
#     accuracy                           1.00     68939
#    macro avg       0.98      0.98      0.98     68939
# weighted avg       1.00      1.00      1.00     68939
# C:\Users\sylhu\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\sylhu\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\sylhu\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
