# %% [markdown]
# @channel **Hello Everyone,**

# %% [markdown]
# **2024-02-13 `22.4 Big-Data-Databricks`**

# %% [markdown]
# **Objectives**
#
# * Describe the purpose of Databricks, and identify two of its key features and a use case.
# * Set up a Databricks environment.
# * Identify the key components of a Databricks environment.
# * Navigate the Databricks workspace using `dbutils`.
# * Import data into a new notebook using the following sources: Parquet, CSV, and S3.
# * Explain the advantage of Parquet as a big-data storage format.
# * Perform complex data analysis using Python and SQL interfaces, including joins.
# * Identify two advantages of using Databricks over PySpark in data analysis.

# %% [markdown]
# **What!!!???!!!** We have our first “Day 4”.  Day 4 of Big Data covers one of the current (2021) industry leaders in the Big Data Processing Space, DataBricks.  In a nutshell, DataBricks is a collaborative environment to work with Spark, however, it’s features and benefits make it so much more than that.  There are TONS of videos and tutorials out there for DataBricks.  Here is the link to the companies, “getting started” page and most importantly the link to the community edition of DataBricks (FREE).
#
# [Databricks "Getting Started"  - Long read](https://docs.databricks.com/onboarding/index.html)
#
# PLEASE SIGN UP AT THIS LINK BEFORE NEXT CLASS:
# [Databricks Community Edition](https://community.cloud.databricks.com/login.html)

# %% [markdown]
# **Presentation**
# * [22.4-Databricks](https://git.bootcampcontent.com/University-of-California---Berkeley/UCB-VIRT-DATA-PT-08-2023-U-LOLC/-/blob/main/Slides/Data-22.4-Databricks.pdf)

# %% [markdown]
# **Signup**
#
# * [Databricks Community Edition Signup](https://git.bootcampcontent.com/University-of-California---Berkeley/UCB-VIRT-DATA-PT-08-2023-U-LOLC/-/blob/main/01-Lesson-Plans/22-Big-Data/4/Activities/01-Stu_Sign_up/Resources/signup.pdf)
# * [Creating_Databricks_Community_Edition_Account](https://git.bootcampcontent.com/University-of-California---Berkeley/UCB-VIRT-DATA-PT-08-2023-U-LOLC/-/blob/main/01-Lesson-Plans/22-Big-Data/4/Activities/01-Stu_Sign_up/Resources/Creating_Databricks_Community_Edition_Account.pdf)
# * [Getting_Started](https://git.bootcampcontent.com/University-of-California---Berkeley/UCB-VIRT-DATA-PT-08-2023-U-LOLC/-/blob/main/01-Lesson-Plans/22-Big-Data/4/Activities/01-Stu_Sign_up/Resources/databricks_signup_getting_started.md)

# %% [markdown]
# **Best wishes.**

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 3.01 Students Do: Sign Up for Databricks (0:10)

# %% [markdown]
# ![image.png](attachment:358de875-0e64-4622-93a0-4812e4ec811a.png)

# %% [markdown]
# # Get Started with Databricks
#
# In this activity, you will sign up for a Databricks Community Edition account.
#
# ### Instructions
#
# 1. Open the following link to sign up for a [Community Edition account](https://community.cloud.databricks.com/login.html). If you don't have an account, then click "Sign Up", which will open a new webpage.
#
#     ![databricks community editions login page](01-Stu_Sign_up/Images/databricks_CE_login_1.png)
#
# 2. On the next page, fill out the required information and click "Get Started For Free."
#
#     ![databricks signup form for required information](01-Stu_Sign_up/Images/databricks_signup_form.png)
#
# 3. You will be redirected to signing up for the standard databricks account. **DO NOT click any of the cloud provider options.** To use the Community Edition, click on "Get started with Community Edition."
#
#     ![databricks getting started with the community edition](01-Stu_Sign_up/Images/databricks_getstartedwithCE.png)
#
# 4. Next, you will be asked to go through a verification process before you are able to use the Community Edition.
#
#     ![Verify your databricks account](01-Stu_Sign_up/Images/verifying_databricks_account.png)
#
# 5. Once you complete the process, you'll get a notice to check your email.
#
#     ![Check your email](01-Stu_Sign_up/Images/check_your_email.png)
#
# 6. Click on the link to verify your email address. You'll be asked to reset your password. Create a new password, and then log in to the Community Edition using your new password.
#
#     ![databricks community editions login page](01-Stu_Sign_up/Images/databricks_CE_login_2.png)
#
#
# Explore the Databricks landing page.
#
# ## Bonus
#
# Use the documentation provided or the quick start tutorial to create a Databricks cluster.
#
# ---

# %% [markdown]
# [Databricks Community Edition Signup](https://ucb.bootcampcontent.com/UCB-Coding-Bootcamp/UCB-VIRT-DATA-PT-11-2022-U-LOLC/-/blob/main/22-Big-Data/4/Activities/01-Stu_Sign_up/Resources/signup.pdf)

# %% [markdown]
# ## Getting Started with the Community Edition
#
# * Once you have logged into your Databricks Community Edition account you'll see the Data Science and Engineering landing page.
#
#     ![Databricks community edition landing page](01-Stu_Sign_up/Images/databricks_landing_page.png)
#
# * On the landing page there are four options to choose from:
#     * A quick start tutorial to help you create a cluster, attach a notebook to your cluster, create a table for a dataset, query the table using SQL, create a table and a graph, and create a DataFrame.
#     * Create a new notebook, like a Jupyter Notebook.
#     * Import data
#     * Connect to external software, like Tableau, Power BI and many more. **Note:** the Community Edition does not allow connections to external software.
#
# * You can use the quick start tutorial to get familiar with Databricks, or you can use the following steps to get started.
#
#     * Before you create a notebook you have to create a cluster. On the navigation pane on the left side of the landing page, click on the the "+" and select "Cluster".
#
#         ![Create a Databricks cluster](01-Stu_Sign_up/Images/databricks_create_cluster.png)
#
#     * You may use the default runtime settings, `9.1 LTS (Scala 2.12, Spark 3.1.2)`, or select an alternate version.
#
#          ![Chose runtime settings for yourc cluster](01-Stu_Sign_up/Images/databricks_select_cluster.png)
#
#     * Next, enter a name for your cluster.
#
#         ![Name your cluster](01-Stu_Sign_up/Images/databricks_name_cluster.png)
#
#     * Once you provide a name for your cluster click "Create Cluster" button at the top of the "Create Cluster" page.
#
#         ![Create your cluster](01-Stu_Sign_up/Images/create_databricks_cluster.png)
#
#     * After you click "Create Cluster" a progress circle icon will spin while the cluster is being created. This may take a few minutes.
#
#         ![creation of cluster instance](01-Stu_Sign_up/Images/databricks_first_cluster.png)
#
# ---

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 3.02 Instructor Do: Databricks Demo (0:15)

# %% [markdown]
# #### Using the Interface Tabs
#
# Click the Databricks tab and explain how to navigate the Databricks interface.
#
#
#   ![Databricks tabs](../Images/Databricks_tabs.png)
#
#   * This interface allows us to perform common tasks like uploading a dataset or creating a new notebook.
#
# Click the Workspace tab, and then explain that this is where we'll find notebooks and other assets.
#
#   ![Databricks workspace tab](../Images/workspace_tab.png)
#
# Click on "Create" and select "Cluster". This is where clusters are created and managed. We can also manage job clusters on this tab, but the capability is limited in the free Community Edition account.
#
#   ![Databricks cluster tab](../Images/cluster_tab.png)
#
# Before you create a notebook, you have to create a cluster. Click the "Create Cluster" button.
#
# Use the default runtime settings, `11.3 LTS (Scala 2.12, Spark 3.3.0)`, or select an alternate version.
#
#   ![Chose runtime settings for your cluster](../Images/databricks_select_cluster.png)
#
# Enter a name for your cluster.
#
#   ![Name your cluster](../Images/databricks_name_cluster.png)
#
# Click the "Create Cluster" button at the top of the "Create Cluster" page.
#
#   ![Create your cluster](../Images/create_databricks_cluster.png)
#
# After clicking "Create Cluster", a progress circle icon will spin while the cluster is being created. This may take a few minutes.
#
#   ![creation of cluster instance](../Images/databricks_first_cluster.png)
#
# #### Upload a Dataset
#
# In the Databricks tab, demonstrate how to create a new table. First, click "Create", then click "Table", and then click "Create Table".
#
#   ![Create a new table](../Images/create_table.png)
#
# Next, upload a dataset by dragging `CT_fires_2015.csv`, `CT_fires_2015Copy.csv`, and `food_prices.parquet` to the "Files" area, then click “Create Table in Notebook.”
#
#   ![upload data and create table in notebook](../Images/upload_data.png)
#
# * Point out that you have the option of giving the table a name.
#
# Explain that both Google Colab and Databricks can run Spark notebooks in the cloud.
#
# Attach the cluster that you created to the notebook by using the dropdown list in the top right of the window to select the cluster created in the previous step.
#
#   ![attach the cluster](../Images/databricks_attach_cluster.png)
#
# Databricks automatically loads the dataset into a Spark DataFrame. However, this may not always create what we want. Click the play arrow or press the Shift and Enter (or Return) keys to run the cell. Go over the following details:
#
#   ![First DataFrame](../Images/df1_displayed.png)
#
# * The CSV file is stored in `/FileStore/tables`.
#
# * Databricks shows a preview of the DataFrame, but the column names haven't been read properly.
#
# Ask the class why the column names are not correct.
#
# * Answer: The `header` option is set to `false`.
#
# #### Use the dbutils File System
#
# Next, you’ll explain the basics of the `dbutils` file system.
#
# To start, click “Add Cell Below.” In the new cell, run the command to list the contents of `FileStore/tables`.
#
#   ![Add cells to notebook](../Images/add_cells.png)
#
#   ```python
#   dbutils.fs.ls("/FileStore/tables/")
#   ```
#
# * `dbutils` stands for Databricks utilities.
#
# * `fs` stands for File System.
#
# * `dbutils.fs` is functionally similar to the command line interface that students have used previously (Terminal or Git Bash).
#
# * Send out the link to the [dbutils.fs documentation](https://docs.databricks.com/data/databricks-file-system.html) so students can reference it for more information.
#
# #### Remove a File with dbutils (Optional)
#
# Show how to remove a file with `dbutils`.
#
#   ```python
#   dbutils.fs.rm("/FileStore/tables/CT_fires_2015Copy.csv")
#   ```
#
# * Running `dbutils.fs.ls("/FileStore/tables")` again will show that the file was deleted.
#
# #### Manually Load a Dataset
#
# Next, load the fires dataset into a Spark DataFrame manually.
#
#   ```python
#   df2 = spark.read.csv(file_location, inferSchema=True, header=True)
#   df2.show(5)
#   ```
#
#     ![df2](Images/df2_displayed.png)
#
# * The column headings were read correctly because we set `header` to `True`.
#
# * `df2.show(5)` returns a preview of the DataFrame. Since there are too many columns to display at once, we should use `display(df2)`.
#
# #### Use the display Function
#
# Explain that `display` is a special Databricks-specific command as you show students how to use it.
#
#   ![Sort and visualize the data](../Images/display_sort_visualizations.png)
#
# * Like `show`, `display` returns a preview of the DataFrame, but it offers additional features.
#
# * By clicking the arrow on a column header, we can sort the DataFrame by that column.
#
# * We can also create a basic visualization by clicking on the "+" sign and selecting "New Visualization", which is highlighted at the top left of the image above.
#
# #### Work with Multiple Programming Languages
#
# Next, we will show that it’s possible to work in Databricks in multiple languages. The default language for a notebook cell is Python. However, we can also run R, SQL, and Scala in the same notebook. As an example, enter the following R code.
#
#   ![Use other programming languages](../Images/other_programming_languages.png)
#
# * The magic command `%r` allows us to run R code in a specific cell.
#
# Create a temporary table from the DataFrame and run a SQL query on it by using the following code:
#
#   ```python
#   df2.createOrReplaceTempView("fire")
#   ```
#   ```sql
#   %sql
#   SELECT *
#   FROM fire
#   LIMIT 5;
#   ```
#
# * By creating a temporary table, we can query a Spark DataFrame with SQL queries. We’ll name our temporary table `fire`.
#
# * The second cell contains the `%sql` magic command, specifying that this cell will run SQL code.
#
# * The SQL query returns the same preview of the DataFrame as `display` and provides the same sorting and visualization capabilities.
#
# #### Create, Use, and Delete Widgets (Optional)
#
# In this section, you will demonstrate how to create a widget in a SQL cell. Note that the widget code should be placed in its own notebook cell. If you choose to skip this section, tell the students to consult the notebook on their own to review the code for this task.
#
# Use the following code to create the widget:
#
#   ```sql
#   CREATE WIDGET TEXT Location DEFAULT "tx"
#   ```
#
# * This command creates a text widget at the top of the notebook that we can used to select rows by column Location.
#
# Next, scroll across the output table and copy the "Location" of the "RIVERTON VOLUNTEER FIRE DEPT" add paste it into the widget box:
#
#   ```
#   Wallens Hill1 RD06065
#   ```
#
#  Next, run the following code to show how to retrieve the data that contains the contents in the widget:
#
#   ```sql
#   %sql
#   SELECT *
#   FROM fire
#   WHERE fire.Location = getArgument("Location")
#   LIMIT 5;
#   ```
#
# * The `getArgument` function retrieves the row containing the "Location", `Wallens Hill1 RD06065`, from the widget.
#
#     ![Get data from the widget](../Images/data_from_widget.png)
#
#  Show how to delete a widget. Here’s the code:
#
#   ```sql
#   REMOVE WIDGET Location
#   ```
#
# #### Work with Parquet Files
#
# Demonstrate how to read in a Parquet file by using the following code:
#
#   ```python
#   # Load a parquet file
#   food_df = spark.read.format("parquet").load("/FileStore/tables/food_prices.parquet")
#
#   # Display the data.
#   display(food_df)
#   ```
#
#   ![Parquet files](../Images/parquet_table.png)
#
# The advantage of using Parquet files in a big data context is that we can create a temporary view, which will load the data much faster for subsequent queries. Create a temporary view with the following code:
#
#   ```python
#   # A parquet formatted DataFrame has all the same methods as a row-based DataFrame.
#   # We can convert the DataFrame to a view and run SQL queries.
#   food_df.createOrReplaceTempView('p_food_prices')
#   ```
#
# With a temporary view we can run SQL queries using a SparkSQL format as follows:
#
#   ```python
#   # Run a SQL query on the view.
#   spark.sql("""select item, avg(price) from p_food_prices group by item""").show(truncate=False)
#   ```
#
# Or, using the `%sql` magic command as follows:
#
#   ```sql
#   SELECT item, avg(price)
#   FROM p_food_prices
#   GROUP BY item;
#   ```
#
#   ![Filtering a parquet file](../Images/temp_view_sql_query.png)
#
# **Important**: When exiting a notebook, students must detach it from its cluster.
#
# First, click the down arrow on the cluster and then select "detach".
#
#   ![detach a cluster](../Images/detach_cluster.png)
#
# Also explain that we can reattach a notebook that has timed out or has been detached from a cluster by selecting the cluster.
#
# #### Import and Export a Databricks Notebook
#
# Show students how to export and import a Databricks notebook. Explain that this will be important when we check solution files for the activities.
#
# First, click the down arrow on the cluster and then select "detach".
#
#   ![export a notebook](../Images/export_ntoebook.png)
#
# * DBC is the extension for Databricks notebook archives.
#
#   ![import](../Images/import_files.png)
#
# * Import a DBC notebook to Databricks.
#
# * Once we import the notebook, the notebook name appears in the workspace.
#
# Ask the students to state the differences between running Spark on Colab (in previous classes) and running Spark on Databricks.
#
# * Unlike Colab, Databricks requires no setup code to use Spark because it is designed to run Spark.
#
# * Databricks offers additional functionality beyond standard Spark, such as `display` and widgets.
#
# Recap what was covered in this Databricks demo: uploading datasets, creating DataFrames, basic file navigation, basic data analysis and visualization, and attaching and detaching clusters.

# %% [markdown]
# ## Overview
#
# This notebook will show you how to create and query a table or DataFrame that you uploaded to DBFS. [DBFS](https://docs.databricks.com/user-guide/dbfs-databricks-file-system.html) is a Databricks File System that allows you to store data for querying inside of Databricks. This notebook assumes that you have a file already inside of DBFS that you would like to read from.
#
# This notebook is written in **Python** so the default cell type is Python. However, you can use different languages by using the `%LANGUAGE` syntax. Python, Scala, SQL, and R are all supported.

# %%
# File location and type
file_location = "/FileStore/tables/CT_fires_2015Copy.csv"
file_type = "csv"

# CSV options
infer_schema = "false"
first_row_is_header = "false"
delimiter = ","
 
# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df)

# %%
# Show the files stored in tables.
dbutils.fs.ls("/FileStore/tables/")

# %%
# Delete a the CT_fires_2015Copy.csv file.
dbutils.fs.rm("/FileStore/tables/CT_fires_2015Copy.csv")

# %%
# Show the files stored in tables.
dbutils.fs.ls("/FileStore/tables/")

# %%
# File location and type
file_location = "/FileStore/tables/CT_fires_2015.csv"
file_type = "csv"

# CSV options
infer_schema = "false"
first_row_is_header = "false"
delimiter = ","
 
# The applied options are for CSV files. For other file types, these will be ignored.
fires_df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(fires_df)

# %%
# Create a new Spark DataFrame with the CT_fires_2015.csv file. 
fires_df2 = spark.read.csv(file_location, inferSchema=True, header=True)
fires_df2.show(5)

# %%
# Display the fires_df2 DataFrame. 
display(fires_df2)

# %%
# %r
#  Run the following r code. 
n = c(2, 3, 5)
print(n)

# %%
# Create a temporary view of the fires_df2 DataFrame.
fires_df2.createOrReplaceTempView("fire")

# %%
# %sql
-- Retrieve the first five rows of the temporary view. 
SELECT *
FROM fire
LIMIT 5;

# %%
# %sql
-- Create a widget with the default value of "tx" 
CREATE WIDGET TEXT Location DEFAULT "tx"

# %%
# %sql
-- Type in the "Wallens Hill1 RD06065" in the widget and run the following query.
SELECT *
FROM fire
WHERE fire.Location = getArgument("Location")
LIMIT 5;

# %%
# %sql
-- Remove the widget.
REMOVE WIDGET Location

# %%
# Load a parquet file
food_df = spark.read.format("parquet").load("/FileStore/tables/food_prices.parquet")

# Display the data. 
display(food_df)

# %%
# A parquet formatted DataFrame has all the same methods as a row-based DataFrame.
# We can convert the DataFrame to a view and run SQL queries. 
food_df.createOrReplaceTempView('p_food_prices')

# %%
# Run a SQL query on the view. 
spark.sql("""select item, avg(price) from p_food_prices group by item""").show(truncate=False)

# %%
# %sql
-- Get the average price for each item. 
SELECT item, avg(price)
FROM p_food_prices
GROUP BY item;

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 3.03 Students Do: Databricks Basics (0:15)

# %% [markdown]
# # Databricks Basics
#
# In this activity, you will create a Databricks notebook and then perform basic data analysis and visualization by using Python and SQL interfaces.
#
#
# ## Instructions
#
# As a new data analyst at XYZ Corporation, you need to familiarize yourself with the Databricks interface. Your manager has asked you to learn how to upload datasets, perform basic file navigation, and conduct data analysis by using Databricks.
#
# Complete the following tasks:
#
# * Upload `vehicles.csv` and `vehicles.parquet` to Databricks.
#
# * Create a blank Databricks notebook.
#
# * Use `dbutils` to note the location of the CSV.
#
# * Create a Spark DataFrame of the dataset and preview the DataFrame.
#
# * Create a PySpark query to obtain the number of vehicles per sale by manufacturer.
#
# * Create a bar chart of the results.
#
# * Perform the same query and visualization by using SQL. Remember that you will need to create a temporary table.
#
# ## Bonus
#
# Complete the following tasks:
#
# * Upload `vehicles.parquet` to Databricks and load only the following columns of the dataset into a Spark DataFrame: year, manufacturer, and transmission.
#
# * Using PySpark, obtain the number of vehicles per sale by manufacturer.
#
# * Create a bar chart of the results.
#
# ## References
#
# Data for this dataset was generated by edX Boot Camps LLC, and is intended for educational purposes only.
#
# ---

# %%
# Show all the files. 
dbutils.fs.ls("/FileStore/tables")

# %%
# Load the vehicles.csv file into a DataFrame.
file_location = '/FileStore/tables/vehicles.csv'
df = spark.read.csv(file_location, inferSchema=True, header=True)
# Display the DataFrame.
display(df)

# %%
# Get the number of each model using a groupby. 
count_df = df.groupBy("manufacturer").count()
count_df.show()

# %%
# Display the DataFrame and create a bar chart.
display(count_df)

# %%
# Create a temporary view of the DataFrame
df.createOrReplaceTempView("vehicles")

# %%
# %sql
--  Write a query that shows the top five rows of the temporary view.
SELECT *
FROM vehicles
LIMIT 5;

# %%
# %sql
-- Write a query that returns the number of vehicles by manufacturer and create a bar chart.
SELECT manufacturer, COUNT(*) AS vehicle_number
FROM vehicles
GROUP BY manufacturer;

# %%
# Bonus: Load the parquet file and load the following columns: year, manufacturer, and transmission.
vehicles_parquet_df = spark.read.format("parquet").load("/FileStore/tables/vehicles.parquet").select("year", "manufacturer", "transmission")
 
# Display the data.
display(vehicles_parquet_df)

# %%
# Get the number of vehicles by manufacturer. 
vehicles_parquet_df2 = vehicles_parquet_df.groupBy("manufacturer").count()

# Display the data and create a bar chart.
display(vehicles_parquet_df2)

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 3.04 Instructor Do: Joins (0:15)

# %%
# Load the user_device.csv and user_usage.csv files from an AWS S3 bucket into Spark DataFrames.
user_device = 's3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/user_device.csv'
user_usage = 's3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/user_usage.csv'

user_device_df = spark.read.csv(user_device, inferSchema=True, header=True)
display(user_device_df)

user_usage_df = spark.read.csv(user_usage, inferSchema=True, header=True)
display(user_usage_df)

# %%
# Merge the two DataFrames on the "use_id" column. 
merged = user_device_df.join(user_usage_df, on=['use_id'], how='inner')

# Display the merged DataFrames
display(merged)

# %%
# Get the average monthly data usage per platform. 
merged.groupBy("platform").agg({"monthly_mb": "avg"}).show()

# %%
# Create temporary views of each original DataFrame. 
user_device_df.createOrReplaceTempView('device')
user_usage_df.createOrReplaceTempView('usage')

# %%
# %sql
-- Get the average monthly data usage per platform.
SELECT AVG(monthly_mb), platform
FROM usage
JOIN device
ON usage.use_id = device.use_id
GROUP BY platform;

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 3.05 Students Do: Joining Animal Species (15 min)

# %% [markdown]
# # Joins in Databricks
#
# In this activity, you will perform queries on datasets using both PySpark and SQL interfaces in Databricks.
#
# ## Background
#
# The ability to query information that is spread out in multiple tables and DataFrames is a crucial skill in data analytics. Data analysts and data scientists often work with data in multiple tables or sources. A nonprofit client has asked you to analyze wildlife data by performing joins across data sources.
#
# You will work with two sources of data and join them. Here are the links to the files on AWS S3:
#
#   * s3://2u-data-curriculum-team/dataviz-classroom/v1.1/22-big-data/species.csv
#
#   * s3://2u-data-curriculum-team/dataviz-classroom/v1.1/22-big-data/surveys.csv
#
# **Note**: If AWS is unavailable, you’ll need to manually upload the included CSV files to Databricks.
#
# ## Instructions
#
# Complete the following tasks by using the PySpark interface.
#
# * Read in the CSV files using the provided links to create a Spark DataFrame for each file.
#
# * Use `display` to preview the DataFrames.
#
# * Count the number of rows in each DataFrame.
#
# * Join the two DataFrames to answer the following question: How many birds are in the dataset?
#
# * Join the two DataFrames to answer the following question: How many rodents were recorded in 1977?
#
# * To perform SQL queries, you must create a temporary view for each DataFrame.
#
# Complete the following tasks using the SQL interface.
#
# * Create a preview of the first five rows for each table.
#
# * Join the two tables to answer the following question: How many birds are in the dataset?
#
# * Join the two tables to answer the following question: How many rodents were recorded in 1977?
#
# **Hint**: Both PySpark and SQL require you to specify the type of join being performed and the columns to be joined.
#
# ## References
#
# **Publication:** S. K. Morgan Ernest, Thomas J. Valone, and James H. Brown. 2009. Long-term monitoring and experimental manipulation of a Chihuahuan Desert ecosystem near Portal, Arizona, USA. Ecology 90:1708.
#
# **Files:** Tracy Teal. (2015) Portal Mammals. [https://github.com/tracykteal/data](https://github.com/tracykteal/data)
#
# ---

# %%
# Create variables for the S3 files.
species_data = 's3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/species.csv'
survey_data = 's3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/surveys.csv'

# %%
# Read in the species.csv file.
species_df = spark.read.csv(species_data, inferSchema=True, header=True)
display(species_df)

# %%
# Read in the survey.csv file.
survey_df = spark.read.csv(survey_data, inferSchema=True, header=True)
display(survey_df)

# %%
# Get the number of records in the species_df.
species_df.count()

# %%
# Get the number of records in the surveys_df.
survey_df.count()

# %%
# How many birds are there in the dataset?
joined_table = species_df.join(survey_df, species_df.species_id == survey_df.species_id, how='inner')
results = joined_table.filter(species_df.taxa == 'Bird').count()
print(results)

# %%
# How many rodents were recorded in 1978?
results2 = joined_table.filter(species_df.taxa=='Rodent').filter(survey_df.year==1977).count()
print(results2)

# %%
# Create a temp view to query in SQL
species = species_df.createOrReplaceTempView('species')

# %%
# Create a temp view to query in SQL
survey = survey_df.createOrReplaceTempView('survey')

# %%
# %sql
SELECT * 
FROM species 
LIMIT 5;

# %%
# %sql
-- Create a preview of the first five rows.
SELECT *
FROM survey
LIMIT 5;

# %%
# %sql
-- How many birds are in the dataset?
SELECT COUNT(*)
FROM species
INNER JOIN survey ON species.species_id = survey.species_id
WHERE species.taxa = 'Bird';

# %%
# %sql
-- How many rodents were recorded in 1977?
SELECT COUNT(*)
FROM species
INNER JOIN survey ON species.species_id = survey.species_id
WHERE species.taxa = 'Rodent'
AND survey.year = 1977;

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### BREAK (0:10)

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 3.06 Groups Do: Database Analysis (40 min)

# %% [markdown]
# # Group Activity
#
# In this activity, you will work in groups of three or four to perform data analysis using a database of a fictional company called Northwind. You’ll put together all the skills you learned today and in this course, including the following:
# * Loading multiple data sources
# * Analyzing data
# * Visualizing data
# * Presenting data findings
#
# Use SQL (not PySpark) to perform all queries.
#
# **Note**: Collaboration is key for this activity. It’s unlikely that any one person will be able to complete all of the tasks in the allotted time. Work with your team!
#
# ## Files
# Get the data files for this activity from the following links. If S3 is unavailable, you can also find the files in the Resources folder.
#
#   ```python
#   s3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/categories.csv
#   s3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/customers.csv
#   s3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/employee-territories.csv
#   s3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/employees.csv
#   s3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/order-details.csv
#   s3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/orders.csv
#   s3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/products.csv
#   s3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/regions.csv
#   s3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/shippers.csv
#   s3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/suppliers.csv
#   s3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/territories.csv
#   ```
# ## Instructions
#
# Complete the following tasks:
# * For each data file, create a Spark DataFrame and a temporary view. **Hint**: You may find it helpful to create a for loop.
# * Run `spark.catalog.listTables()` to verify that the tables have been created.
# * To establish relationships between tables, you can print the schema of each DataFrame, or you may search online for an ERD of the Northwind database.
#
# The management of Northwind has asked your team to provide the following information. Where appropriate, create a chart to visualize the results. Remember to use SQL to query the database.
#
# * Create a list of all countries to which orders have been shipped.
#   * How many total orders have been placed?
#   * How many orders have been shipped to each country?
# * For each product, list its product ID, product name, and the company name.
#   * Which five countries have the heaviest shipments, on average?
#   * Which 10 companies have placed the most orders? List the contact name of each company.
# * Sort by descending order all customers by total amount spent.
# * Sort by descending order the customers with a total amount spent greater than $20,000.
# * Sort by descending order all employees by the number of orders sold.
#   * How many employees account for approximately half the orders sold? (You do not have to use SQL to answer this question. A rough estimate is ok.)
# * List customers who have never placed an order.
# * List in descending order the products with the highest level of discount.
# **Note**: You don’t have to limit yourself to these queries. Feel free to create your own queries to create data insights.
# * Use the results of your data analysis to create a brief report (3–5 slides) for management. Your report should include the following information.
#   * Three actionable recommendations. Support each recommendation with a data finding.
#   * Visualizations where appropriate.
# * Send the link of your Google Slides presentation to your instructor.
#
# ## References
# Rakesh Singh. (2016). Northwind. [https://github.com/rakeshsingh/northwind-for-spark](https://github.com/rakeshsingh/northwind-for-spark)
#
# ---

# %%
dbutils.fs.ls('FileStore/tables/northwind')

# %%
file_links = {
    "categories": "s3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/categories.csv",
    "customers": "s3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/customers.csv",
    "employee_territories": "s3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/employee-territories.csv",
    "employees": "s3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/employees.csv",
    "order_details": "s3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/order-details.csv",
    "orders": "s3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/orders.csv",
    "products": "s3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/products.csv",
    "regions": "s3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/regions.csv",
    "shippers": "s3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/shippers.csv",
    "suppliers": "s3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/suppliers.csv",
    "territories": "s3://2u-data-curriculum-team/dataviz-classroom/v1.2/22-big-data/4/territories.csv"
}

# %%
# Use a for loop to create Spark DataFrames for each file and then create a temporary view for each DataFrame.
for table_name, table_path in file_links.items():
    df_name = table_name + "_df"
    df_name = spark.read.csv(table_path, inferSchema=True, header=True)
    df_name.createOrReplaceTempView(table_name)

# %%
# List all the tables.
spark.catalog.listTables()

# %%
# %sql
-- A list of all countries that orders have been shipped to
SELECT DISTINCT ShipCountry
FROM orders;

# %%
# %sql
-- How many total orders have been placed?
SELECT COUNT(*)
FROM orders;

# %%
# %sql
-- How many orders have been shipped to each country?
SELECT ShipCountry, COUNT(*) As NumOrders
FROM orders
GROUP BY ShipCountry
ORDER BY NumOrders DESC;

# %%
# %sql
-- For each product, list its product ID, product name, and the company name
SELECT ProductID, ProductName, CompanyName
FROM products
JOIN suppliers
ON products.SupplierID = suppliers.SupplierID;

# %%
# %sql
--How many products exist in each category?
SELECT CategoryName, COUNT(*) AS ProductCount
FROM categories
JOIN products
ON categories.CategoryID = products.CategoryID
GROUP BY CategoryName
ORDER BY ProductCount DESC;

# %%
# %sql
-- Which 5 countries have the most customers?
SELECT Country, COUNT(*) AS NumberOfCustomers
FROM customers
GROUP BY Country
ORDER BY NumberOfCustomers DESC
LIMIT 5;

# %%
# %sql
--Which 5 countries have the heaviest shipments, on average?
SELECT ShipCountry, AVG(Freight) AS AverageFreight
FROM orders
GROUP BY ShipCountry
ORDER BY AverageFreight DESC
LIMIT 5;

# %%
# %sql
-- Which 10 companies have placed the most orders?
-- List the company contacts as well
SELECT CompanyName, ContactName, COUNT(OrderID) as NumberOfOrders
FROM customers c
JOIN orders o
ON c.CustomerID = o.CustomerID
GROUP BY CompanyName, ContactName
ORDER BY NumberOfOrders DESC
LIMIT 10;

# %%
# %sql
-- Which customers are the biggest spenders in terms of total amount spent on orders?
SELECT customers.CompanyName, SUM(Quantity * UnitPrice) AS TotalSpending
FROM customers
JOIN orders
ON customers.CustomerID = orders.CustomerID
JOIN order_details
ON orders.OrderID = order_details.OrderID
GROUP BY customers.CustomerID, customers.CompanyName
ORDER BY TotalSpending DESC;

# %%
# %sql
-- Which customers are the biggest spenders in terms of total amount spent on orders?
-- List only companies with a total spending of greater than 20,000.
SELECT customers.CompanyName, SUM(Quantity * UnitPrice) AS TotalSpending
FROM customers
JOIN orders
ON customers.CustomerID = orders.CustomerID
JOIN order_details
ON orders.OrderID = order_details.OrderID
GROUP BY customers.CustomerID, customers.CompanyName
HAVING TotalSpending > 20000
ORDER BY TotalSpending DESC;

# %%
# %sql
-- Which employees have sold the most orders?
SELECT LastName, FirstName, COUNT(OrderID) AS NumOrders
FROM employees e
JOIN orders o
ON e.EmployeeID = o.EmployeeID
GROUP BY LastName, FirstName
ORDER BY NumOrders DESC;

# %%
# %sql
-- List customer IDs of customers who have never placed an order.
SELECT c.CustomerID, o.CustomerID
FROM customers c
LEFT JOIN orders o
ON c.CustomerID = o.CustomerID
WHERE o.CustomerID IS NULL;

# %%
# %sql
-- Show the top 15 order IDs
SELECT o.OrderID, COUNT(*) AS TotalOrders
FROM orders o
JOIN order_details od
ON o.OrderID = od.OrderID
GROUP BY o.OrderID
ORDER BY TotalOrders DESC
LIMIT 15;

# %%
# %sql
-- List the most heavily discounted products in descending order
SELECT p.ProductName, od.Discount
FROM products p
JOIN order_details od
ON p.ProductID = od.ProductID
ORDER BY od.Discount DESC;

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### Rating Class Objectives
#
# * rate your understanding using 1-5 method in each objective

# %%
title = "22.4 Big-Data - Databricks"
objectives = [
    "Describe the purpose of Databricks, and identify two of its key features and a use case",
    "Set up a Databricks environment",
    "Identify the key components of a Databricks environment",
    "Navigate the Databricks workspace using dbutils",
    "Import data into a new notebook using the following sources: Parquet, CSV, and S3",
    "Explain the advantage of Parquet as a big-data storage format",
    "Perform complex data analysis using Python and SQL interfaces, including joins",
    "Identify two advantages of using Databricks over PySpark in data analysis",
]
rating = []
total = 0
for i in range(len(objectives)):
    rate = input(objectives[i]+"? ")
    total += int(rate)
    rating.append(objectives[i] + ". (" + rate + "/5)")
print("="*96)
print(f"Self Evaluation for: {title}")
print("-"*24)
for i in rating:
    print(i)
print("-"*64)
print("Average: " + str(total/len(objectives)))
