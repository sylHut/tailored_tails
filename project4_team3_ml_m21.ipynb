# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import pandas as pd

# %%
# Import the master data
master_df = pd.read_csv("Resources/preprocessed_doggy_2024.02.23_c_ML.csv")
master_df.head()
# Out:
#    Unnamed: 0    Borough dog_friendly income_cat  grooming_frequency  \
# 0           0      Bronx          Yes     middle                 0.4
# 1           1  Manhattan          Yes       high                 0.8
# 2           2  Manhattan          Yes       high                 1.0
# 3           3   Brooklyn          Yes        low                 0.4
# 4           4   Brooklyn          Yes       high                 0.4
#
#    shedding  energy_level  trainability  demeanor          size  \
# 0       0.4           0.8           0.8       1.0  Small 9-35lb
# 1       0.2           0.6           0.6       1.0      Toy >9lb
# 2       0.2           0.6           0.2       0.8      Toy >9lb
# 3       0.8           0.6           1.0       0.6  Small 9-35lb
# 4       0.4           0.4           1.0       0.8      Toy >9lb
#
#    life_expectancy lifetime_cost                          Breed
# 0              0.6           Low                          Boxer
# 1              0.8        Medium                        Maltese
# 2              0.8        Medium              Yorkshire Terrier
# 3              0.4           Low            German Shepherd Dog
# 4              0.8        Medium  Cavalier King Charles Spaniel

# %%
# Determine the number of unique values in each column.
master_df.nunique()
# Out:
# Unnamed: 0            275755
# Borough                    5
# dog_friendly               2
# income_cat                 3
# grooming_frequency         5
# shedding                   5
# energy_level               5
# trainability               5
# demeanor                   4
# size                       5
# life_expectancy            4
# lifetime_cost              3
# Breed                     50
# dtype: int64

# %%
# View the data types
master_df.dtypes
# Out:
# Unnamed: 0              int64
# Borough                object
# dog_friendly           object
# income_cat             object
# grooming_frequency    float64
# shedding              float64
# energy_level          float64
# trainability          float64
# demeanor              float64
# size                   object
# life_expectancy       float64
# lifetime_cost          object
# Breed                  object
# dtype: object

# %%
# Split our preprocessed data into our features and target arrays
y = master_df["Breed"]
X = master_df.drop(["Breed"],axis=1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Use get_dummies to convert category types to numbers
y = pd.get_dummies(y, dtype=int)
X = pd.get_dummies(X, dtype=int)

# %%
# View the conversion
display(y.sample(5))
display(X.head())
# Out:
#         Australian Cattle Dog  Australian Shepherd  Basset Hound  Beagle  \
# 145078                      0                    0             0       0
# 156423                      0                    0             0       0
# 232511                      0                    0             0       0
# 411                         0                    0             0       0
# 87736                       0                    0             0       0
#
#         Belgian Malinois  Bernese Mountain Dog  Bichon Frise  Bloodhound  \
# 145078                 0                     0             0           0
# 156423                 0                     0             0           0
# 232511                 0                     0             0           0
# 411                    0                     0             0           0
# 87736                  0                     0             0           0
#
#         Border Collie  Boston Terrier  ...  Rhodesian Ridgeback  Rottweiler  \
# 145078              0               0  ...                    0           0
# 156423              0               0  ...                    0           0
# 232511              0               0  ...                    0           0
# 411                 0               0  ...                    0           0
# 87736               0               0  ...                    0           0
#
#         Shetland Sheepdog  Shiba Inu  Shih Tzu  Siberian Husky  Vizsla  \
# 145078                  0          0         0               0       0
# 156423                  0          0         0               0       0
# 232511                  0          0         0               0       0
# 411                     0          0         0               0       0
# 87736                   0          0         0               0       0
#
#         Weimaraner  West Highland White Terrier  Yorkshire Terrier
# 145078           0                            0                  0
# 156423           0                            0                  1
# 232511           0                            0                  0
# 411              0                            0                  0
# 87736            0                            0                  0
#
# [5 rows x 50 columns]
#    Unnamed: 0  grooming_frequency  shedding  energy_level  trainability  \
# 0           0                 0.4       0.4           0.8           0.8
# 1           1                 0.8       0.2           0.6           0.6
# 2           2                 1.0       0.2           0.6           0.2
# 3           3                 0.4       0.8           0.6           1.0
# 4           4                 0.4       0.4           0.4           1.0
#
#    demeanor  life_expectancy  Borough_Bronx  Borough_Brooklyn  \
# 0       1.0              0.6              1                 0
# 1       1.0              0.8              0                 0
# 2       0.8              0.8              0                 0
# 3       0.6              0.4              0                 1
# 4       0.8              0.8              0                 1
#
#    Borough_Manhattan  ...  income_cat_low  income_cat_middle  \
# 0                  0  ...               0                  1
# 1                  1  ...               0                  0
# 2                  1  ...               0                  0
# 3                  0  ...               1                  0
# 4                  0  ...               0                  0
#
#    size_Giant <75lb  size_Large 55-75lb  size_Medium 35-55lb  \
# 0                 0                   0                    0
# 1                 0                   0                    0
# 2                 0                   0                    0
# 3                 0                   0                    0
# 4                 0                   0                    0
#
#    size_Small 9-35lb  size_Toy >9lb  lifetime_cost_High  lifetime_cost_Low  \
# 0                  1              0                   0                  1
# 1                  0              1                   0                  0
# 2                  0              1                   0                  0
# 3                  1              0                   0                  1
# 4                  0              1                   0                  0
#
#    lifetime_cost_Medium
# 0                     0
# 1                     1
# 2                     1
# 3                     0
# 4                     1
#
# [5 rows x 25 columns]

# %%
string_value = master_df['Borough']
float_value = float(string_value)
print(float_value)


string_value = pd.Series(master_df['Borough'])  
float_series = series.astype(float)
print(float_series)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 string_value = master_df['Borough']
# ----> 2 float_series = series.astype(float)
#       3 print(float_series)
#
# NameError: name 'series' is not defined

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17600\2127983596.py in ?()
#       1 # Create a StandardScaler instances
#       2 scaler = StandardScaler()
#       3
#       4 # Fit the StandardScaler
# ----> 5 X_scaler = scaler.fit(X_train)
#       6
#       7 # Scale the data
#       8 X_train_scaled = X_scaler.transform(X_train)
#
# ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     872             Fitted scaler.
#     873         """
#     874         # Reset internal state before fitting
#     875         self._reset()
# --> 876         return self.partial_fit(X, y, sample_weight)
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1347                 skip_parameter_validation=(
#    1348                     prefer_skip_nested_validation or global_skip_validation
#    1349                 )
#    1350             ):
# -> 1351                 return fit_method(estimator, *args, **kwargs)
#
# ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     908         self : object
#     909             Fitted scaler.
#     910         """
#     911         first_call = not hasattr(self, "n_samples_seen_")
# --> 912         X = self._validate_data(
#     913             X,
#     914             accept_sparse=("csr", "csc"),
#     915             dtype=FLOAT_DTYPES,
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     629                 out = y
#     630             else:
#     631                 out = X, y
#     632         elif not no_val_X and no_val_y:
# --> 633             out = check_array(X, input_name="X", **check_params)
#     634         elif no_val_X and not no_val_y:
#     635             out = _check_y(y, **check_params)
#     636         else:
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     948                         )
#     949                     array = xp.astype(array, dtype, copy=False)
#     950                 else:
#     951                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 952             except ComplexWarning as complex_warning:
#     953                 raise ValueError(
#     954                     "Complex data not supported\n{}\n".format(array)
#     955                 ) from complex_warning
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp)
#     517         # Use NumPy API to support order
#     518         if copy is True:
#     519             array = numpy.array(array, order=order, dtype=dtype)
#     520         else:
# --> 521             array = numpy.asarray(array, order=order, dtype=dtype)
#     522
#     523         # At this point array is a NumPy ndarray. We convert it to an array
#     524         # container that is consistent with the input's namespace.
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, dtype)
#    1996     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    1997         values = self._values
# -> 1998         arr = np.asarray(values, dtype=dtype)
#    1999         if (
#    2000             astype_is_view(values.dtype, arr.dtype)
#    2001             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'Queens'

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Attempt #1
# layer1 = 10 : activation function = relu
# layer2 = 20 : activation function = relu

# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 10
hidden_nodes_layer2 = 20


nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                440
#
#  dense_1 (Dense)             (None, 20)                220
#
#  dense_2 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 681 (2.66 KB)
# Trainable params: 681 (2.66 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5914 - accuracy: 0.7088
# Epoch 2/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5608 - accuracy: 0.7282
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5571 - accuracy: 0.7296
# Epoch 4/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5550 - accuracy: 0.7301
# Epoch 5/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5534 - accuracy: 0.7307
# Epoch 6/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5525 - accuracy: 0.7329
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5518 - accuracy: 0.7311
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7329
# Epoch 9/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5502 - accuracy: 0.7321
# Epoch 10/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5495 - accuracy: 0.7336
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5494 - accuracy: 0.7317
# Epoch 12/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5482 - accuracy: 0.7335
# Epoch 13/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5485 - accuracy: 0.7338
# Epoch 14/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5477 - accuracy: 0.7332
# Epoch 15/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5475 - accuracy: 0.7336
# Epoch 16/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5474 - accuracy: 0.7339
# Epoch 17/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5470 - accuracy: 0.7337
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5467 - accuracy: 0.7341
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5466 - accuracy: 0.7346
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5466 - accuracy: 0.7352
# Epoch 21/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5463 - accuracy: 0.7335
# Epoch 22/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5461 - accuracy: 0.7344
# Epoch 23/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5459 - accuracy: 0.7342
# Epoch 24/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5462 - accuracy: 0.7343
# Epoch 25/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5455 - accuracy: 0.7347
# Epoch 26/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5453 - accuracy: 0.7349
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5455 - accuracy: 0.7350
# Epoch 28/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5452 - accuracy: 0.7347
# Epoch 29/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5449 - accuracy: 0.7353
# Epoch 30/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5448 - accuracy: 0.7351
# Epoch 31/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5447 - accuracy: 0.7349
# Epoch 32/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5446 - accuracy: 0.7355
# Epoch 33/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5451 - accuracy: 0.7349
# Epoch 34/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5447 - accuracy: 0.7354
# Epoch 35/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5447 - accuracy: 0.7355
# Epoch 36/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5445 - accuracy: 0.7343
# Epoch 37/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5444 - accuracy: 0.7360
# Epoch 38/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5443 - accuracy: 0.7358
# Epoch 39/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5439 - accuracy: 0.7355
# Epoch 40/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5441 - accuracy: 0.7353
# Epoch 41/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5442 - accuracy: 0.7360
# Epoch 42/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5441 - accuracy: 0.7360
# Epoch 43/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5434 - accuracy: 0.7367
# Epoch 44/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5440 - accuracy: 0.7358
# Epoch 45/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5438 - accuracy: 0.7365
# Epoch 46/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5439 - accuracy: 0.7360
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5437 - accuracy: 0.7356
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5436 - accuracy: 0.7360
# Epoch 49/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5436 - accuracy: 0.7364
# Epoch 50/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5432 - accuracy: 0.7363
# Epoch 51/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5432 - accuracy: 0.7365
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5435 - accuracy: 0.7364
# Epoch 53/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5434 - accuracy: 0.7372
# Epoch 54/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5434 - accuracy: 0.7376
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5434 - accuracy: 0.7357
# Epoch 56/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5430 - accuracy: 0.7370
# Epoch 57/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5434 - accuracy: 0.7378
# Epoch 58/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5429 - accuracy: 0.7368
# Epoch 59/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5433 - accuracy: 0.7362
# Epoch 60/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5430 - accuracy: 0.7364
# Epoch 61/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5430 - accuracy: 0.7364
# Epoch 62/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5433 - accuracy: 0.7367
# Epoch 63/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5428 - accuracy: 0.7374
# Epoch 64/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5433 - accuracy: 0.7359
# Epoch 65/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5427 - accuracy: 0.7371
# Epoch 66/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5428 - accuracy: 0.7363
# Epoch 67/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5428 - accuracy: 0.7369
# Epoch 68/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5424 - accuracy: 0.7372
# Epoch 69/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5428 - accuracy: 0.7375
# Epoch 70/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5430 - accuracy: 0.7363
# Epoch 71/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5428 - accuracy: 0.7378
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5426 - accuracy: 0.7372
# Epoch 73/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5426 - accuracy: 0.7371
# Epoch 74/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5424 - accuracy: 0.7374
# Epoch 75/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5423 - accuracy: 0.7378
# Epoch 76/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5427 - accuracy: 0.7370
# Epoch 77/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5423 - accuracy: 0.7368
# Epoch 78/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5425 - accuracy: 0.7369
# Epoch 79/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5420 - accuracy: 0.7366
# Epoch 80/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5424 - accuracy: 0.7372
# Epoch 81/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5422 - accuracy: 0.7364
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5421 - accuracy: 0.7376
# Epoch 83/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5422 - accuracy: 0.7376
# Epoch 84/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5418 - accuracy: 0.7374
# Epoch 85/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5420 - accuracy: 0.7372
# Epoch 86/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5420 - accuracy: 0.7371
# Epoch 87/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5420 - accuracy: 0.7364
# Epoch 88/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5421 - accuracy: 0.7378
# Epoch 89/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5418 - accuracy: 0.7371
# Epoch 90/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5418 - accuracy: 0.7365
# Epoch 91/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5419 - accuracy: 0.7364
# Epoch 92/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5416 - accuracy: 0.7377
# Epoch 93/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5418 - accuracy: 0.7367
# Epoch 94/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5418 - accuracy: 0.7365
# Epoch 95/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5414 - accuracy: 0.7361
# Epoch 96/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5415 - accuracy: 0.7376
# Epoch 97/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5416 - accuracy: 0.7372
# Epoch 98/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5417 - accuracy: 0.7359
# Epoch 99/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5418 - accuracy: 0.7367
# Epoch 100/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5416 - accuracy: 0.7380

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5534 - accuracy: 0.7269 - 479ms/epoch - 2ms/step
# Loss: 0.5534024238586426, Accuracy: 0.7268804907798767

# %%
# Export our model to HDF5 file
nn.save('AlphabetSoupCharity.h5')
