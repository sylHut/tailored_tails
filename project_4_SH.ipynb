# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler
import pandas as pd
# import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # IRS Data

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
irs_data_df = pd.read_csv("Resources/IRS_NY_2020.csv")
irs_data_df
# Out:
#       ZipCode  Number of returns  \
# 0       10001              15590
# 1       10002              41020
# 2       10003              25780
# 3       10004               2220
# 4       10005               5530
# ...       ...                ...
# 1533    14901               5460
# 1534    14903               3630
# 1535    14904               6900
# 1536    14905               4330
# 1537    99999              85240
#
#       Total income Amount (In thousand of dollars)  Average total income
# 0                                          2830868          181582.29630
# 1                                          2697332           65756.50902
# 2                                          6953211          269713.38250
# 3                                          1047897          472025.67570
# 4                                          2374656          429413.38160
# ...                                            ...                   ...
# 1533                                        222977           40838.27839
# 1534                                        246522           67912.39669
# 1535                                        287843           41716.37681
# 1536                                        318597           73578.98383
# 1537                                      17053833          200068.43030
#
# [1538 rows x 4 columns]

# %%
# View the data types
print(irs_data_df.dtypes)
# Out:
# ZipCode                                           int64
# Number of returns                                 int64
# Total income Amount (In thousand of dollars)      int64
# Average total income                            float64
# dtype: object

# %%
# Convert float64 data to integers
irs_data_df['Average total income'] = irs_data_df['Average total income'].astype('int')
print(irs_data_df.dtypes)
# Out:
# ZipCode                                         int64
# Number of returns                               int64
# Total income Amount (In thousand of dollars)    int64
# Average total income                            int32
# dtype: object

# %% [markdown]
# # NYC Licensing Data

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
nyc_licensing_df = pd.read_csv("Resources/NYC_Dog_Licensing_Dataset_20240218.csv")
nyc_licensing_df
# Out:
# C:\Users\sylhu\AppData\Local\Temp\ipykernel_19012\1022353120.py:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   nyc_licensing_df = pd.read_csv("Resources/NYC_Dog_Licensing_Dataset_20240218.csv")
#        AnimalName AnimalGender AnimalBirthYear  \
# 0           PAIGE            F            2014
# 1            YOGI            M            2010
# 2             ALI            M            2014
# 3           QUEEN            F            2013
# 4            LOLA            F            2009
# ...           ...          ...             ...
# 616885       SKYE            F            2016
# 616886    UNKNOWN            F            2023
# 616887      MUNYU            M            2009
# 616888      SAINT            M            2021
# 616889       BABY            F            2021
#
#                                    BreedName  ZipCode LicenseIssuedDate  \
# 0       American Pit Bull Mix / Pit Bull Mix  10035.0        09/12/2014
# 1                                      Boxer  10465.0        09/12/2014
# 2                                    Basenji  10013.0        09/12/2014
# 3                           Akita Crossbreed  10013.0        09/12/2014
# 4                                    Maltese  10028.0        09/12/2014
# ...                                      ...      ...               ...
# 616885                        Great Pyrenees  11218.0        11/01/2023
# 616886                   Shih Tzu Crossbreed  10022.0        11/01/2023
# 616887                           Poodle, Toy  11355.0        11/01/2023
# 616888                               Unknown  11412.0        11/01/2023
# 616889                               Unknown  10473.0        11/01/2023
#
#        LicenseExpiredDate  Extract Year
# 0              09/12/2017          2016
# 1              10/02/2017          2016
# 2              09/12/2019          2016
# 3              09/12/2017          2016
# 4              10/09/2017          2016
# ...                   ...           ...
# 616885         12/02/2024          2023
# 616886         11/01/2024          2023
# 616887         11/24/2024          2023
# 616888         11/01/2024          2023
# 616889         11/01/2024          2023
#
# [616890 rows x 8 columns]

# %%
# View the data types
print(nyc_licensing_df.dtypes)
# Out:
# AnimalName             object
# AnimalGender           object
# AnimalBirthYear        object
# BreedName              object
# ZipCode               float64
# LicenseIssuedDate      object
# LicenseExpiredDate     object
# Extract Year            int64
# dtype: object

# %%
# Replace NaN with 0 
nyc_licensing_df['ZipCode'].fillna(0, inplace=True)

# Convert to integer
nyc_licensing_df['ZipCode'] = nyc_licensing_df['ZipCode'].astype('int')
print(nyc_licensing_df.dtypes)
# Out:
# AnimalName            object
# AnimalGender          object
# AnimalBirthYear       object
# BreedName             object
# ZipCode                int32
# LicenseIssuedDate     object
# LicenseExpiredDate    object
# Extract Year           int64
# dtype: object

# %%
# Determine the number of unique values in each column.
nyc_licensing_df.nunique()
# Out:
# AnimalName            32083
# AnimalGender              2
# AnimalBirthYear          76
# BreedName              1591
# ZipCode                 911
# LicenseIssuedDate      3337
# LicenseExpiredDate     4869
# Extract Year              5
# dtype: int64

# %% [markdown]
# # Merge IRS NY data with NYC Licensing Zip Code data

# %%
# Combine two csv files by using the ZipCode Column.
merged_df = pd.merge(irs_data_df, nyc_licensing_df, on='ZipCode', how='left')
merged_df
# Out:
#         ZipCode  Number of returns  \
# 0         10001              15590
# 1         10001              15590
# 2         10001              15590
# 3         10001              15590
# 4         10001              15590
# ...         ...                ...
# 612861    14901               5460
# 612862    14903               3630
# 612863    14904               6900
# 612864    14905               4330
# 612865    99999              85240
#
#         Total income Amount (In thousand of dollars)  Average total income  \
# 0                                            2830868                181582
# 1                                            2830868                181582
# 2                                            2830868                181582
# 3                                            2830868                181582
# 4                                            2830868                181582
# ...                                              ...                   ...
# 612861                                        222977                 40838
# 612862                                        246522                 67912
# 612863                                        287843                 41716
# 612864                                        318597                 73578
# 612865                                      17053833                200068
#
#        AnimalName AnimalGender AnimalBirthYear             BreedName  \
# 0          BANDIT            M            2014              Shih Tzu
# 1          SCOOBY            M            2012  Schnauzer, Miniature
# 2           GRACE            F            2011             Shiba Inu
# 3          TUCKER            M            2005     Bull Dog, English
# 4           DAISY            F            2012     Bull Dog, English
# ...           ...          ...             ...                   ...
# 612861    CHESTER            M            2021              Maltipoo
# 612862       ZEKE            M            2022   German Shepherd Dog
# 612863        NaN          NaN             NaN                   NaN
# 612864        NaN          NaN             NaN                   NaN
# 612865        NaN          NaN             NaN                   NaN
#
#        LicenseIssuedDate LicenseExpiredDate  Extract Year
# 0             10/07/2014         10/07/2016        2016.0
# 1             11/19/2014         09/06/2016        2016.0
# 2             11/25/2014         11/25/2016        2016.0
# 3             12/03/2014         01/30/2016        2016.0
# 4             01/09/2015         01/09/2017        2016.0
# ...                  ...                ...           ...
# 612861        01/16/2023         01/27/2024        2023.0
# 612862        07/28/2022         07/28/2023        2023.0
# 612863               NaN                NaN           NaN
# 612864               NaN                NaN           NaN
# 612865               NaN                NaN           NaN
#
# [612866 rows x 11 columns]

# %%
# Drop the non-beneficial columns
merged_df.drop(['Number of returns', 'Total income Amount (In thousand of dollars)', 'AnimalName'], axis=1, inplace=True)
merged_df
# Out:
#         ZipCode  Average total income AnimalGender AnimalBirthYear  \
# 0         10001                181582            M            2014
# 1         10001                181582            M            2012
# 2         10001                181582            F            2011
# 3         10001                181582            M            2005
# 4         10001                181582            F            2012
# ...         ...                   ...          ...             ...
# 612861    14901                 40838            M            2021
# 612862    14903                 67912            M            2022
# 612863    14904                 41716          NaN             NaN
# 612864    14905                 73578          NaN             NaN
# 612865    99999                200068          NaN             NaN
#
#                    BreedName LicenseIssuedDate LicenseExpiredDate  \
# 0                   Shih Tzu        10/07/2014         10/07/2016
# 1       Schnauzer, Miniature        11/19/2014         09/06/2016
# 2                  Shiba Inu        11/25/2014         11/25/2016
# 3          Bull Dog, English        12/03/2014         01/30/2016
# 4          Bull Dog, English        01/09/2015         01/09/2017
# ...                      ...               ...                ...
# 612861              Maltipoo        01/16/2023         01/27/2024
# 612862   German Shepherd Dog        07/28/2022         07/28/2023
# 612863                   NaN               NaN                NaN
# 612864                   NaN               NaN                NaN
# 612865                   NaN               NaN                NaN
#
#         Extract Year
# 0             2016.0
# 1             2016.0
# 2             2016.0
# 3             2016.0
# 4             2016.0
# ...              ...
# 612861        2023.0
# 612862        2023.0
# 612863           NaN
# 612864           NaN
# 612865           NaN
#
# [612866 rows x 8 columns]

# %%
# View the data types
print(merged_df.dtypes)
# Out:
# ZipCode                   int64
# Average total income      int32
# AnimalGender             object
# AnimalBirthYear          object
# BreedName                object
# LicenseIssuedDate        object
# LicenseExpiredDate       object
# Extract Year            float64
# dtype: object

# %%
# Convert to integer
merged_df['Average total income'] = merged_df['Average total income'].astype('int')
print(merged_df.dtypes)
# Out:
# ZipCode                   int64
# Average total income      int32
# AnimalGender             object
# AnimalBirthYear          object
# BreedName                object
# LicenseIssuedDate        object
# LicenseExpiredDate       object
# Extract Year            float64
# dtype: object

# %%
# Replace NaN with 0 
merged_df['Extract Year'].fillna(0, inplace=True)

# Convert to integer
merged_df['Extract Year'] = merged_df['Extract Year'].astype('int')
print(merged_df.dtypes)
# Out:
# ZipCode                  int64
# Average total income     int32
# AnimalGender            object
# AnimalBirthYear         object
# BreedName               object
# LicenseIssuedDate       object
# LicenseExpiredDate      object
# Extract Year             int32
# dtype: object

# %%
# Determine the number of unique values in each column.
merged_df.nunique()
# Out:
# ZipCode                 1538
# Average total income    1515
# AnimalGender               2
# AnimalBirthYear           76
# BreedName               1584
# LicenseIssuedDate       3337
# LicenseExpiredDate      4868
# Extract Year               6
# dtype: int64

# %%
# Export DataFrame to a CSV file
merged_df.to_csv('merged_df.csv', index=False)

# %% [markdown]
# # Analyze Data - Review Correlations

# %%
# Calculate the correlation between the Average-total-income and ZipCode
correlation = merged_df['Average total income'].corr(merged_df['ZipCode'])
print(correlation)
# Out:
# -0.5135861842173098

# %% [markdown]
# # Group ZipCodes to 5 NYC Boroughs

# %%
# Brooklyn:11201-11256
# Manhattan:10001-10282
# Queens:11004-11109, 11351-11697
# Staten Island :10301-10314
# Bronx: 10451-10475

# %%
# Make five Boroughs
def categorize_zipcode(zip_code):
    # Brooklyn
    if 11201 <= zip_code <= 11256:
        return 'Brooklyn'
    # Manhattan
    elif 10001 <= zip_code <= 10282:
        return 'Manhattan'
    # Queens
    elif (11004 <= zip_code <= 11109) or (11351 <= zip_code <= 11697):
        return 'Queens'
    # Staten Island
    elif 10301 <= zip_code <= 10314:
        return 'Staten Island'
    # Bronx
    elif 10451 <= zip_code <= 10475:
        return 'Bronx'
    else:
        return 'Others'

# Applying the function to the DataFrame
merged_df['Borough'] = merged_df['ZipCode'].apply(categorize_zipcode)

# Display the DataFrame to verify the categorization
merged_df
# Out:
#         ZipCode  Average total income AnimalGender AnimalBirthYear  \
# 0         10001                181582            M            2014
# 1         10001                181582            M            2012
# 2         10001                181582            F            2011
# 3         10001                181582            M            2005
# 4         10001                181582            F            2012
# ...         ...                   ...          ...             ...
# 612861    14901                 40838            M            2021
# 612862    14903                 67912            M            2022
# 612863    14904                 41716          NaN             NaN
# 612864    14905                 73578          NaN             NaN
# 612865    99999                200068          NaN             NaN
#
#                    BreedName LicenseIssuedDate LicenseExpiredDate  \
# 0                   Shih Tzu        10/07/2014         10/07/2016
# 1       Schnauzer, Miniature        11/19/2014         09/06/2016
# 2                  Shiba Inu        11/25/2014         11/25/2016
# 3          Bull Dog, English        12/03/2014         01/30/2016
# 4          Bull Dog, English        01/09/2015         01/09/2017
# ...                      ...               ...                ...
# 612861              Maltipoo        01/16/2023         01/27/2024
# 612862   German Shepherd Dog        07/28/2022         07/28/2023
# 612863                   NaN               NaN                NaN
# 612864                   NaN               NaN                NaN
# 612865                   NaN               NaN                NaN
#
#         Extract Year    Borough
# 0               2016  Manhattan
# 1               2016  Manhattan
# 2               2016  Manhattan
# 3               2016  Manhattan
# 4               2016  Manhattan
# ...              ...        ...
# 612861          2023     Others
# 612862          2023     Others
# 612863             0     Others
# 612864             0     Others
# 612865             0     Others
#
# [612866 rows x 9 columns]

# %%
# Drop rows where 'Borough' column has the value 'Others'
boroughs_df = merged_df[merged_df['Borough'] != 'Others']
boroughs_df
# Out:
#         ZipCode  Average total income AnimalGender AnimalBirthYear  \
# 0         10001                181582            M            2014
# 1         10001                181582            M            2012
# 2         10001                181582            F            2011
# 3         10001                181582            M            2005
# 4         10001                181582            F            2012
# ...         ...                   ...          ...             ...
# 611288    11697                110414            F            2021
# 611289    11697                110414            M            2016
# 611290    11697                110414            F            2012
# 611291    11697                110414            F            2016
# 611292    11697                110414            M            2018
#
#                             BreedName LicenseIssuedDate LicenseExpiredDate  \
# 0                            Shih Tzu        10/07/2014         10/07/2016
# 1                Schnauzer, Miniature        11/19/2014         09/06/2016
# 2                           Shiba Inu        11/25/2014         11/25/2016
# 3                   Bull Dog, English        12/03/2014         01/30/2016
# 4                   Bull Dog, English        01/09/2015         01/09/2017
# ...                               ...               ...                ...
# 611288     German Shepherd Crossbreed        08/24/2023         10/09/2024
# 611289                        Unknown        09/12/2023         08/26/2024
# 611290            German Shepherd Dog        09/13/2023         11/03/2024
# 611291  Labrador Retriever Crossbreed        09/15/2023         05/25/2024
# 611292                         Vizsla        09/21/2023         09/21/2028
#
#         Extract Year    Borough
# 0               2016  Manhattan
# 1               2016  Manhattan
# 2               2016  Manhattan
# 3               2016  Manhattan
# 4               2016  Manhattan
# ...              ...        ...
# 611288          2023     Queens
# 611289          2023     Queens
# 611290          2023     Queens
# 611291          2023     Queens
# 611292          2023     Queens
#
# [610252 rows x 9 columns]

# %%
# View the data types
boroughs_df.dtypes
# Out:
# ZipCode                  int64
# Average total income     int32
# AnimalGender            object
# AnimalBirthYear         object
# BreedName               object
# LicenseIssuedDate       object
# LicenseExpiredDate      object
# Extract Year             int32
# Borough                 object
# dtype: object

# %% [markdown]
# # Clean up the BreedName and Drop unnecessary columns

# %%
# Clean up the BreedName to match to the other team mate's breedname
## Get all unique values in the 'BreedName' column
unique_breeds = boroughs_df['BreedName'].unique()

# Printing all unique names
for name in unique_breeds:
    print(name)
# Out:
# Shih Tzu
# Schnauzer, Miniature
# Shiba Inu
# Bull Dog, English
# Yorkshire Terrier
# Miniature Pinscher
# Australian Shepherd
# French Bulldog
# Boston Terrier
# Unknown
# Labrador Retriever
# Cavalier King Charles Spaniel
# Cocker Spaniel
# Bull Dog, French
# Labrador Retriever Crossbreed
# Dachshund, Long Haired
# American Pit Bull Terrier/Pit Bull
# Vizsla
# Golden Retriever
# Maltese
# German Shepherd Dog
# Welsh Corgi, Pembroke
# Dachshund
# Poodle, Miniature
# West High White Terrier
# American Pit Bull Mix / Pit Bull Mix
# Chihuahua
# Wheaton Terrier
# Pomeranian
# Pug
# Beagle Crossbreed
# Havanese
# Border Collie
# Jack Russell Terrier
# Shetland Sheepdog
# American Staffordshire Terrier
# Rhodesian Ridgeback
# German Shepherd Crossbreed
# Poodle, Toy
# Puggle
# English Cocker Spaniel
# Bichon Frise
# Tibetan Terrier
# Lhasa Apso
# Wire Fox Terrier
# Terrier mix
# Australian Cattle Dog
# Beagle
# Chihuahua Crossbreed
# Treeing Walker Coonhound
# Silky Terrier
# Brussels Griffon
# Boxer
# Morkie
# Poodle
# Bernese Mountain Dog
# Shih Tzu Crossbreed
# Chow Chow
# Siberian Husky
# Staffordshire Bull Terrier
# Poodle Crossbreed
# Flat-Coated Retriever
# Australian Kelpie
# Otterhound
# Dachshund Smooth Coat Miniature
# Poodle, Standard
# Dachshund Smooth Coat
# Basenji
# American Eskimo dog
# Parson Russell Terrier
# Scottish Terrier
# Samoyed
# Terrier Crossbreed
# Australian Silky Terrier
# Labradoodle
# Great Dane
# Maltese Crossbreed
# Australian Cattledog
# Soft Coated Wheaten Terrier
# Schnauzer Crossbreed
# Italian Greyhound
# Yorkshire Terrier Crossbreed
# Rottweiler
# Pembroke Welsh Corgi
# Tibetan Spaniel
# Miniature Schnauzer
# Bassett Hound
# Dachshund, Long Haired Miniature
# Shar-Pei, Chinese
# Manchester Terrier
# Dachshund, Wirehaired
# Goldendoodle
# Coton de Tulear
# Leonberger
# Rat Terrier
# Papillon
# Border Terrier
# Chesapeake Bay Retriever
# American Bully
# Belgian Malinois
# Cairn Terrier
# Pointer
# Bull Terrier
# Doberman Pinscher
# Pekingese
# Pomeranian Crossbreed
# Portuguese Water Dog
# Collie
# Irish Terrier
# Bulldog
# West Highland White Terrier
# Welsh Terrier
# Basset Hound
# Miniature American Shepherd
# Boxer Crossbreed
# Siberian Husky Crossbreed
# Jindo
# Pembroke Welsh Corgi Crossbreed
# Rat Terrier Crossbreed
# Thai Ridgeback
# Pug Crossbreed
# WELSH CORGI   X
# Collie Mix
# shepherd mix
# TERR / SHEP
# Crossbreed
# Yorkie-Bichon
# Labra Doodle
# Bugg
# Puggle/Beagle Mix
# Pit Bull/Mastiff
# ZUCHON
# YORKIE POODLE
# Pit Ter Lab
# Maltese/Pomeranian
# Poo-Chon
# lab mix
# AMER PIT BULL TERR MIX
# SHIH TZU
# Collie /Springer Terrier Mix
# SHIBA INU/GERM SHEPHERD
# SHIH TZU X
# X golden wolf hound
# COCA-POO
# LAB RETRIEVER MIX
# Havashire
# BULLDOG MIX
# Chow / Retriever Mixed
# zuchon
# Shepherd  Mix
# TERR MIX
# pom-chi
# POOCHON
# Bull Mastiff Mix
# TOY POODLE MIX
# AUST CTTLE DG X
# boggle
# FOX TERRIER X
# Bichon/Shih Tzu
# LHASA APSO/TERR
# chihuahua/mini pinscher
# AUST.CATTLE DOG
# pit bull
# Rottweiler/Labrador Retriever
# Poemranan Mix
# WHEATON TERRIER/KING CHARLES CHU MIX
# Shih Tzu/Bichon
# Sheltie/Jack Russ Mix
# Zuchon
# Yorkie
# Dalmation/Terrier/Poodle
# YORKSHI/MALTESE
# Shih Tzu/Terrier
# Corgi or Jack Russell mixed with Black Lab and Pit
# min pi n/poodle
# Corgi Mix
# Border Terrier Crossbreed
# YORKER/JACKRUSELL/CHIHUAHUA
# Yorkie Mixed
# Shepherd /Pit Bull Mix
# FEIST MIX
# Chihuahua Mixed
# MALT POODLE
# Cocker Spaniel /Mini Poodle Mix
# chihuahua-yorkie
# BICHON MIX
# Pomeranian/ mix
# Yorkie Poodle
# Red Nose Pit Bull
# BLUE NOSE PIT BULL TERR
# SHIH/MALTESE
# SHIH TZU/MALTESE
# Chihuahua/Yorkie Mix
# Tosa
# Miniature Pin Mix
# Jagdterrier
# shit zu/poodle
# Pyrenean Mastiff
# Pekapoo
# Cocker-Pug
# CHI-POO
# Mini Pinscher/Chihuahua Mix
# Yorkshire Terrier Toy
# BL NS PIT BULL
# Maltese Chihuahua Mix
# MALT/YORKSHIRE TERRIER
# Chow Chow/Bull Terr.Mix
# PITBULL/MASTIFF MIX
# Mixed / ?
# Lab Bord Collie
# Yorkie/fox terrier mix
# Vizsla, mini pin
# Yorkshire/Poodle
# YORKIDOODLE
# Breed Information Not Provided.
# AMERICAN SPANIEL MIX
# maltese westie mix
# cocker spaniel/poodle mix
# Scott Terr/Shih Tsu
# Husky/Labrador Retriever
# GOLDEN RETR/CORGY MIX
# canine
# RED NOSE PIT BULL
# SHORKIE TZU
# Viszla Mix
# Boxer Chow Lab Mix
# Bull Dog Mix
# Matipoo
# Terrier  X
# Shepherd  X
# SHEPHERD/ROTTIX
# Shitzu X
# MALTESE MIX
# SHIH TZU POODLE MIX
# miniature poodle / cocker spaniel
# Fox Terrier Mix
# Poodle/Pompoo
# Tea Cup Poodle
# PINSCHER-CHIH
# BL NOSE PIT BULL
# Xoloitzcuintli/Basset Hound
# retriver mixed
# Maltese/Shih Tzu
# Yorky
# Poodle/ShihTzu
# Teddy-Bear
# rabies,bordetella
# Cigi
# Terrier/Corgi Mix
# BEAGLE MIX
# ShihTzu/Poodle
# LAB/SPANIEL MIX
# YorkshireTerrier /Shih Tzu Mix
# SCHNOODLE X
# MALTESE-SHIHTZU
# POODLE/MALTESE
# Fila Brasileiro
# Havanese/Chihuahua
# Goldendoddle
# Germ Shep/Husky
# Havapeke
# pitbull mix
# BOSTON TERR/MIN BOXER
# TOY AUSTRALIAN SHEPHERD
# Unknown (stray)
# Maltese/ Shih Tzu
# Boston Terrier Mix
# Tibetan Terrier/Havanese Mix
# westie terrier-schnauser mix
# Unknown/Cross
# chih/dach mix
# BICHON/CAIRN
# BEARDED COLLIE MIX
# German Shepherd/Husky
# CATAHOULA LEOPARD CUR
# Shih Tzu / Yorkie Mix
# dach mix
# Papillion Mix
# Beagle/Chihuahua
# Shepherd/Hound/Lab
# MIX
# RUSSEL
# AUS SHEP/HEELER/RET
# MIX-BORDER COLLIE -HUSKY-SHEPHERD
# Cavalier King Charles/Bichon
# mix breed
# Lab/Hound Mix
# Shoorkie
# COCKA POO
# CHIHUAHUA-JACK RUSSELL TERRIER
# chow mix
# Askal
# HOUND TERRIER MIX
# AMERICAN BULLDOG
# BORDER COLLIE/AUSTRALIAN SHEPHERD
# Shih Tzu/ Poodle
# TREEING WALKER COONHOUND
# Chihuahua/Greyhound
# Wheaton Mix
# Labrador - Pit Bull Mix
# Dachshund / Retriever Mix
# Yorkshire Terrier/Dachshund Mix
# COOCKER-POO
# Caroline Dog
# Poodle/Italian Greyhound
# Lab mix
# Carolina mix
# spaniel/terrier?
# Spitz
# maltese/yorkie
# Pit Mix
# Pekingese/Shih Tzu Mix
# Chihuahua/Terrier
# English Pointer Mix
# Yorkshire-Poodle Mix
# POODLE/BICHON
# Schnauzer /Poodle Mix
# AUST SHEPHERD
# AM STAFF TER X
# BERNSES MOUNT DOG MIX
# ITAL GREYHOUND MIX
# retriever mix
# Collie mix
# Chihuahua /Poodle
# mostly labrador retriever
# English Pointer
# Mini Pinscher/ Chihuahua Mix
# Nova Scotia Toller
# BEAGLE/TERR X
# ENGLISH MASTIFF
# LHASA POO
# CHIHUAHUA/JACK RUSSELL MIX
# Rottweiler/Chow Mix
# Italian/Sicilian hound
# SCHNAUZER
# shih tzu / maltese mix
# Chihuahua Short Coat
# Malkie
# welsh terrier
# SHIH POO
# Mixed Terrier
# RUSSKIY TOY SMOOTHHAIRED
# MALTESE/CAV KIN
# LABRADOR/COLLIE
# Poodle/Jack Russel Terrier  mix
# collie
# COOCKAPOO
# CHOW MIX
# Shepherd Mis
# chiweenie
# Pomeranian mix
# Terrier/Shih Tzu
# American Bulldog
# Boston Terrier-Beagle
# Pit Bull  Mix
# Sheltie Poo
# Aust Heller Mix
# PRYNESE/LAB X
# Beagle-Pei
# COCKALIER
# Chihuahua/Dachshund
# BEAGLE/BOXER X
# CHIHUAHUA X
# Labrador/Coon Hound
# Hound Mixed
# Taiwan Mountain Dog
# SHIHT-ZU IMPERIAL
# Westiepoo
# Taiwan Mountain
# Pug/Chihuahua
# Jack Russell X
# Beagle Mixed
# Havachon
# HOUND/PIT BULL
# Shih Tuz/Poodle
# chi-spaniel
# Mutt
# TERRIER
# mix corgi/lab. retriever
# Terrier / Hound
# Mini Shepherd X
# SHIBA INU

# %%
# Dog Breeds
print(f"Total Number of Breeds in Dataset: {boroughs_df['BreedName'].nunique()} \n")
boroughs_df['BreedName'].value_counts().head(50)
# Out:
# Total Number of Breeds in Dataset: 1584
# BreedName
# Unknown                                 54842
# Yorkshire Terrier                       35036
# Shih Tzu                                32183
# Chihuahua                               24426
# Labrador Retriever                      18726
# Maltese                                 18243
# Labrador Retriever Crossbreed           16358
# American Pit Bull Mix / Pit Bull Mix    14969
# Pomeranian                              11802
# Shih Tzu Crossbreed                     11647
# American Pit Bull Terrier/Pit Bull      11524
# Poodle Crossbreed                       10555
# Havanese                                10544
# Chihuahua Crossbreed                     9513
# Golden Retriever                         9122
# Beagle                                   8902
# German Shepherd Dog                      8687
# French Bulldog                           8685
# Goldendoodle                             7683
# Shiba Inu                                7603
# Terrier mix                              7592
# Cavalier King Charles Spaniel            7319
# Jack Russell Terrier                     7153
# Poodle                                   7143
# Poodle, Toy                              6320
# German Shepherd Crossbreed               6296
# Siberian Husky                           6291
# Yorkshire Terrier Crossbreed             6015
# Cocker Spaniel                           6007
# Not Provided                             5841
# Maltese Crossbreed                       5835
# Poodle, Miniature                        5751
# Australian Shepherd                      5662
# Pug                                      5651
# Boston Terrier                           5339
# Labradoodle                              5081
# Bichon Frise                             4973
# Beagle Crossbreed                        4936
# Morkie                                   4802
# Dachshund                                4610
# Maltipoo                                 4061
# Boxer                                    3932
# Schnauzer, Miniature                     3638
# American Staffordshire Terrier           3612
# Miniature Pinscher                       3566
# Terrier Crossbreed                       3484
# Poodle, Standard                         3457
# Bull Dog, English                        3440
# Bichon Frise Crossbreed                  3371
# Miniature Schnauzer                      3287
# Name: count, dtype: int64

# %%
# Create a list of the top 50 dog breed names
t50_breeds = boroughs_df['BreedName'].value_counts().head(51).reset_index()
t50_breeds = t50_breeds['BreedName']
t50_breeds = list(t50_breeds)
t50_breeds = t50_breeds[1:]
print(len(t50_breeds))
t50_breeds
# Out:
# 50
# ['Yorkshire Terrier',
#  'Shih Tzu',
#  'Chihuahua',
#  'Labrador Retriever',
#  'Maltese',
#  'Labrador Retriever Crossbreed',
#  'American Pit Bull Mix / Pit Bull Mix',
#  'Pomeranian',
#  'Shih Tzu Crossbreed',
#  'American Pit Bull Terrier/Pit Bull',
#  'Poodle Crossbreed',
#  'Havanese',
#  'Chihuahua Crossbreed',
#  'Golden Retriever',
#  'Beagle',
#  'German Shepherd Dog',
#  'French Bulldog',
#  'Goldendoodle',
#  'Shiba Inu',
#  'Terrier mix',
#  'Cavalier King Charles Spaniel',
#  'Jack Russell Terrier',
#  'Poodle',
#  'Poodle, Toy',
#  'German Shepherd Crossbreed',
#  'Siberian Husky',
#  'Yorkshire Terrier Crossbreed',
#  'Cocker Spaniel',
#  'Not Provided',
#  'Maltese Crossbreed',
#  'Poodle, Miniature',
#  'Australian Shepherd',
#  'Pug',
#  'Boston Terrier',
#  'Labradoodle',
#  'Bichon Frise',
#  'Beagle Crossbreed',
#  'Morkie',
#  'Dachshund',
#  'Maltipoo',
#  'Boxer',
#  'Schnauzer, Miniature',
#  'American Staffordshire Terrier',
#  'Miniature Pinscher',
#  'Terrier Crossbreed',
#  'Poodle, Standard',
#  'Bull Dog, English',
#  'Bichon Frise Crossbreed',
#  'Miniature Schnauzer',
#  'Puggle']

# %%
# Create a list of the top 50 dog breed names to match other team mate's dataset

desired_breeds_df = pd.DataFrame()

desired_breeds = [
    'French Bulldog', 'Labrador Retriever', 'Golden Retriever',
    'German Shepherd Dog', 'Poodle', 'Bulldog', 'Rottweiler',
    'Beagle', 'Dachshund', 'German Shorthaired Pointer',
    'Pembroke Welsh Corgi', 'Australian Shepherd', 'Yorkshire Terrier',
    'Cavalier King Charles Spaniel', 'Doberman Pinscher', 'Boxer',
    'Miniature Schnauzer', 'Cane Corso', 'Great Dane', 'Shih Tzu',
    'Siberian Husky', 'Bernese Mountain Dog', 'Pomeranian',
    'Boston Terrier', 'Havanese', 'English Springer Spaniel',
    'Shetland Sheepdog', 'Brittany', 'Cocker Spaniel', 'Border Collie',
    'Miniature American Shepherd', 'Belgian Malinois', 'Vizsla',
    'Chihuahua', 'Pug', 'Basset Hound', 'Mastiff', 'Maltese', 'Collie',
    'English Cocker Spaniel', 'Rhodesian Ridgeback', 'Newfoundland',
    'Shiba Inu', 'Weimaraner', 'West Highland White Terrier',
    'Portuguese Water Dog', 'Bichon Frise', 'Australian Cattle Dog',
    'Dalmatian', 'Bloodhound'
]

desired_breeds_df['breeds'] = desired_breeds

# %%
# Drop the rows where dog breed is not in the top 50
t50_licensed_dogs_df = boroughs_df[boroughs_df['BreedName'].isin(desired_breeds_df['breeds'])]

display(t50_licensed_dogs_df.head(), t50_licensed_dogs_df.info(), t50_licensed_dogs_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 277491 entries, 0 to 611292
# Data columns (total 9 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ZipCode               277491 non-null  int64
#  1   Average total income  277491 non-null  int32
#  2   AnimalGender          277474 non-null  object
#  3   AnimalBirthYear       277491 non-null  object
#  4   BreedName             277491 non-null  object
#  5   LicenseIssuedDate     277491 non-null  object
#  6   LicenseExpiredDate    277475 non-null  object
#  7   Extract Year          277491 non-null  int32
#  8   Borough               277491 non-null  object
# dtypes: int32(2), int64(1), object(6)
# memory usage: 19.1+ MB
#    ZipCode  Average total income AnimalGender AnimalBirthYear  \
# 0    10001                181582            M            2014
# 2    10001                181582            F            2011
# 5    10001                181582            M            2014
# 6    10001                181582            F            2014
# 9    10001                181582            M            2009
#
#              BreedName LicenseIssuedDate LicenseExpiredDate  Extract Year  \
# 0             Shih Tzu        10/07/2014         10/07/2016          2016
# 2            Shiba Inu        11/25/2014         11/25/2016          2016
# 5            Shiba Inu        01/13/2015         01/13/2016          2016
# 6    Yorkshire Terrier        01/13/2015         01/13/2016          2016
# 9  Australian Shepherd        01/19/2015         01/19/2016          2016
#
#      Borough
# 0  Manhattan
# 2  Manhattan
# 5  Manhattan
# 6  Manhattan
# 9  Manhattan
# None
#              ZipCode  Average total income   Extract Year
# count  277491.000000         277491.000000  277491.000000
# mean    10688.643275         137060.586963    2019.903600
# std       575.831025         136071.082916       2.790056
# min     10001.000000          30443.000000    2016.000000
# 25%     10032.000000          49044.000000    2017.000000
# 50%     10467.000000          71159.000000    2022.000000
# 75%     11229.000000         173862.000000    2022.000000
# max     11697.000000         768937.000000    2023.000000

# %%
# Drop rows where the ZipCode and AnimalGender is NA/Null
licensed_t50_dogs_df = t50_licensed_dogs_df.copy()
licensed_t50_dogs_df.dropna(subset=['AnimalGender', 'ZipCode'] , inplace=True)

licensed_t50_dogs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 277474 entries, 0 to 611292
# Data columns (total 9 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ZipCode               277474 non-null  int64
#  1   Average total income  277474 non-null  int32
#  2   AnimalGender          277474 non-null  object
#  3   AnimalBirthYear       277474 non-null  object
#  4   BreedName             277474 non-null  object
#  5   LicenseIssuedDate     277474 non-null  object
#  6   LicenseExpiredDate    277458 non-null  object
#  7   Extract Year          277474 non-null  int32
#  8   Borough               277474 non-null  object
# dtypes: int32(2), int64(1), object(6)
# memory usage: 19.1+ MB

# %%
# list the columns
licensed_t50_dogs_df.columns
# Out:
# Index(['ZipCode', 'Average total income', 'AnimalGender', 'AnimalBirthYear',
#        'BreedName', 'LicenseIssuedDate', 'LicenseExpiredDate', 'Extract Year',
#        'Borough'],
#       dtype='object')

# %%
# Drop Unnessary Columns AnimalName, LicenseIssuedDate, LicenseExpiredDate, Extract Year
licensed_t50_dogs_df = licensed_t50_dogs_df.drop(axis=1, labels=['LicenseIssuedDate', 'LicenseExpiredDate', 'Extract Year'])

licensed_t50_dogs_df.columns
# Out:
# Index(['ZipCode', 'Average total income', 'AnimalGender', 'AnimalBirthYear',
#        'BreedName', 'Borough'],
#       dtype='object')

# %%
licensed_t50_dogs_df
# Out:
#         ZipCode  Average total income AnimalGender AnimalBirthYear  \
# 0         10001                181582            M            2014
# 2         10001                181582            F            2011
# 5         10001                181582            M            2014
# 6         10001                181582            F            2014
# 9         10001                181582            M            2009
# ...         ...                   ...          ...             ...
# 611282    11697                110414            M            2011
# 611284    11697                110414            F            2018
# 611285    11697                110414            M            2015
# 611290    11697                110414            F            2012
# 611292    11697                110414            M            2018
#
#                             BreedName    Borough
# 0                            Shih Tzu  Manhattan
# 2                           Shiba Inu  Manhattan
# 5                           Shiba Inu  Manhattan
# 6                   Yorkshire Terrier  Manhattan
# 9                 Australian Shepherd  Manhattan
# ...                               ...        ...
# 611282                        Maltese     Queens
# 611284  Cavalier King Charles Spaniel     Queens
# 611285             Labrador Retriever     Queens
# 611290            German Shepherd Dog     Queens
# 611292                         Vizsla     Queens
#
# [277474 rows x 6 columns]

# %%
# Export DataFrame to a CSV file
licensed_t50_dogs_df.to_csv('licensed_t50_dogs_df.csv', index=False)

# %% [markdown]
# # Join Team mate's dataset by using BreedName column

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
nyc_demo_df = pd.read_csv("Resources/demo_summary_cleaned.csv")
nyc_demo_df
# Out:
#    Unnamed: 0        Borough demo_total_pop  dem_median_age  \
# 0           0          Bronx      1,436,785            33.3
# 1           1       Brooklyn      2,606,852            34.5
# 2           2      Manhattan      1,634,989            36.7
# 3           3         Queens      2,310,011            37.9
# 4           4  Staten Island        473,324            39.6
#
#   demo_housing_units  demo_avg_#_per_household
# 0            522,401                  2.750349
# 1          1,021,747                  2.551367
# 2            866,644                  1.886575
# 3            846,689                  2.728287
# 4            178,603                  2.650146

# %%
# View the data types
nyc_demo_df.dtypes
# Out:
# Unnamed: 0                    int64
# Borough                      object
# demo_total_pop               object
# dem_median_age              float64
# demo_housing_units           object
# demo_avg_#_per_household    float64
# dtype: object

# %%
# Combine two csv files by using the Borough Column.
merged_demo_t50_df = pd.merge(licensed_t50_dogs_df, nyc_demo_df, on='Borough', how='left')
merged_demo_t50_df
# Out:
#         ZipCode  Average total income AnimalGender AnimalBirthYear  \
# 0         10001                181582            M            2014
# 1         10001                181582            F            2011
# 2         10001                181582            M            2014
# 3         10001                181582            F            2014
# 4         10001                181582            M            2009
# ...         ...                   ...          ...             ...
# 277469    11697                110414            M            2011
# 277470    11697                110414            F            2018
# 277471    11697                110414            M            2015
# 277472    11697                110414            F            2012
# 277473    11697                110414            M            2018
#
#                             BreedName    Borough  Unnamed: 0 demo_total_pop  \
# 0                            Shih Tzu  Manhattan           2      1,634,989
# 1                           Shiba Inu  Manhattan           2      1,634,989
# 2                           Shiba Inu  Manhattan           2      1,634,989
# 3                   Yorkshire Terrier  Manhattan           2      1,634,989
# 4                 Australian Shepherd  Manhattan           2      1,634,989
# ...                               ...        ...         ...            ...
# 277469                        Maltese     Queens           3      2,310,011
# 277470  Cavalier King Charles Spaniel     Queens           3      2,310,011
# 277471             Labrador Retriever     Queens           3      2,310,011
# 277472            German Shepherd Dog     Queens           3      2,310,011
# 277473                         Vizsla     Queens           3      2,310,011
#
#         dem_median_age demo_housing_units  demo_avg_#_per_household
# 0                 36.7            866,644                  1.886575
# 1                 36.7            866,644                  1.886575
# 2                 36.7            866,644                  1.886575
# 3                 36.7            866,644                  1.886575
# 4                 36.7            866,644                  1.886575
# ...                ...                ...                       ...
# 277469            37.9            846,689                  2.728287
# 277470            37.9            846,689                  2.728287
# 277471            37.9            846,689                  2.728287
# 277472            37.9            846,689                  2.728287
# 277473            37.9            846,689                  2.728287
#
# [277474 rows x 11 columns]

# %%
# View the data types
merged_demo_t50_df.dtypes
# Out:
# ZipCode                       int64
# Average total income          int32
# AnimalGender                 object
# AnimalBirthYear              object
# BreedName                    object
# Borough                      object
# Unnamed: 0                    int64
# demo_total_pop               object
# dem_median_age              float64
# demo_housing_units           object
# demo_avg_#_per_household    float64
# dtype: object

# %%
# Export DataFrame to a CSV file
merged_demo_t50_df.to_csv('merged_demo_t50_df.csv', index=False)

# %% [markdown]
# # Analyze Data - Review Graphs

# %%
# Calculate the average income per borough
average_income_per_borough = merged_demo_t50_df.groupby('Borough')['Average total income'].mean().reset_index()

# Sort the DataFrame by 'Average total income' in descending order
average_income_per_borough = average_income_per_borough.sort_values(by='Average total income', ascending=False)

# Plotting the average income per borough
plt.figure(figsize=(10, 6))  
sns.barplot(x='Borough', y='Average total income', data=average_income_per_borough)

plt.title('Average Income per Borough')
plt.xlabel('Borough')
plt.ylabel('Average Total Income')

plt.show()

# %%
# Count the number of dogs in each borough and reset index to convert Series to DataFrame for seaborn
dogs_per_borough = merged_demo_t50_df['Borough'].value_counts().reset_index()
dogs_per_borough.columns = ['Borough', 'Number of Dogs']  

# Plotting using seaborn
sns.barplot(x='Borough', y='Number of Dogs', data=dogs_per_borough)

plt.title('Number of Dogs Owned by Each Borough')
plt.xlabel('Borough')
plt.ylabel('Number of Dogs')
plt.xticks(rotation=45)  

plt.show()

# %%
# Income Rank #1
# Filter the DataFrame for only Manhattan borough
manhattan_dogs = merged_demo_t50_df[merged_demo_t50_df['Borough'] == 'Manhattan']

# Count the occurrences of each dog breed in Manhattan
breed_counts = manhattan_dogs['BreedName'].value_counts().reset_index()
breed_counts.columns = ['BreedName', 'Count']  

# Plotting using seaborn
plt.figure(figsize=(12, 8))  
sns.barplot(x='Count', y='BreedName', data=breed_counts[:5], palette='viridis')  

plt.title('Top 5 Dog Breeds in Manhattan')
plt.xlabel('Number of Dogs')
plt.ylabel('Breed Name')

plt.show()

# %%
# Income Rank #2
# Filter the DataFrame for only Brooklyn borough
brooklyn_dogs = merged_demo_t50_df[merged_demo_t50_df['Borough'] == 'Brooklyn']

# Count the occurrences of each dog breed in Brooklyn
breed_counts = brooklyn_dogs['BreedName'].value_counts().reset_index()
breed_counts.columns = ['BreedName', 'Count']  

# Plotting using seaborn
plt.figure(figsize=(12, 8))  
sns.barplot(x='Count', y='BreedName', data=breed_counts[:5], palette='viridis')  

plt.title('Top 5 Dog Breeds in Brooklyn')
plt.xlabel('Number of Dogs')
plt.ylabel('Breed Name')

plt.show()

# %%
# Income Rank #3
# Filter the DataFrame for only Staten Island borough
staten_dogs = merged_demo_t50_df[merged_demo_t50_df['Borough'] == 'Staten Island']

# Count the occurrences of each dog breed in Staten Island
breed_counts = staten_dogs['BreedName'].value_counts().reset_index()
breed_counts.columns = ['BreedName', 'Count']  

# Plotting using seaborn
plt.figure(figsize=(12, 8))  
sns.barplot(x='Count', y='BreedName', data=breed_counts[:5], palette='viridis')  

plt.title('Top 5 Dog Breeds in Staten Island')
plt.xlabel('Number of Dogs')
plt.ylabel('Breed Name')

plt.show()

# %%
# Income Rank #4
# Filter the DataFrame for only Queens borough
queens_dogs = merged_demo_t50_df[merged_demo_t50_df['Borough'] == 'Queens']

# Count the occurrences of each dog breed in Queens
breed_counts = queens_dogs['BreedName'].value_counts().reset_index()
breed_counts.columns = ['BreedName', 'Count']  

# Plotting using seaborn
plt.figure(figsize=(12, 8))  
sns.barplot(x='Count', y='BreedName', data=breed_counts[:5], palette='viridis')  

plt.title('Top 5 Dog Breeds in Queens')
plt.xlabel('Number of Dogs')
plt.ylabel('Breed Name')

plt.show()

# %%
# Income Rank #5
# Filter the DataFrame for only Bronx borough
bronx_dogs = merged_demo_t50_df[merged_demo_t50_df['Borough'] == 'Bronx']

# Count the occurrences of each dog breed in Bronx
breed_counts = bronx_dogs['BreedName'].value_counts().reset_index()
breed_counts.columns = ['BreedName', 'Count']  

# Plotting using seaborn
plt.figure(figsize=(12, 8))  
sns.barplot(x='Count', y='BreedName', data=breed_counts[:5], palette='viridis')  

plt.title('Top 5 Dog Breeds in Bronx')
plt.xlabel('Number of Dogs')
plt.ylabel('Breed Name')

plt.show()
